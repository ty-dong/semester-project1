# %% [markdown]
# What if we build the model from start?
#
# First consider the distance and price.

# %% [markdown]
# ### timeline
#
# #### model 1
#
# basic distance and price
#
# #### model 2
# distance price and no meal
#
# #### model 3
# distance price and evaluation
#
# #### model 4
# hot meal's price and distance
#
# *  beta_price becomes significant
#
# #### model 5
# hot meal's price during lunch and distance
#
# * beta_price still significant, but the extent decreases
#
# #### model 6
# hot meal's price during lunch, distance, and dinner availability
#
# #### model 7
# based on model 5, distance_no_av is taken into consideration
#
# * big improvement on likelihohod
#
# #### model 8
# based on model 7, add variable microwave
#
# #### model 9
# based on model 7, tap beer is considered
#
# #### model 10
# based on model 7, evaluation considered again
#
# * beta_eva is significant
#
# #### model 11
# based on model 10, evaluation is specified only for hot meal during lunch
#
# * beta_eva and beta_price are no longer significant
#
# #### model 12
# remove hot_meal_av, which means evaluation and price * lunch
#
# * sign of beta_price is negative, but beta_price is not significant. Beta_eva is significant
#
# #### model 13
# rescale price
#
# * no difference
#
# #### improve 1
# capacity is considered
#
# * sign of beta_price and beta_eva is reversed
#
# #### improve 2
# remove hot_meal_av from price and evaluation
#
# * sign of coefficient of the two variables are reversed.
#
# #### improve 3
# sandwich is consdiered
#
# * significant, but sign of beta_price is negative and beta_price and beta_eva are not significant.
#
# #### improve 4
# consider different price's influence on employee and student
#
# * sign of beta_employee for price is positive and insignificant, possible to consider price only for student?
#
# #### improve 5
# capacity and sandwich_av are conbined
#
# #### improve 6
# distance specified for different types of food
#
# * big mistake, likelihood increases, AIC BIC increases
#
# #### improve 7
# price specified for different types of food
#
# * most new parameters are corelated with beta_eva, except beta_rest. For restaurants, price matters.
#
# #### improve 8
# evalutaion specified for different types of food
#
# * no much difference
#
# #### improve 9
# specify according to lunch breakfast and afternoon, dinner for distance
#
# * likelihood increases significantly, that is weird, sign of beta_distance is postive, and it is corelated with beta_break_after
#
# #### improve 10
# similar specification, for price

# %%
import biogeme

# %%
import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio

# %%
pandas =pd.read_table("Dataset.dat")

# %%
database = db.Database("Dataset",pandas)

# %%
from headers import *

# %%
exclude = DURATION < 5
database.remove(exclude)

# %%
ASC_BC = Beta('ASC_BC', 0, -100, 100, 0)
ASC_BM = Beta('ASC_BM ', 0, -100, 100, 0)
ASC_ELA = Beta('ASC_ELA ', 0, -100, 100, 0)
ASC_MX = Beta('ASC_MX ', 0, -100, 100, 0)
ASC_PH = Beta('ASC_PH ', 0, -100, 100, 0)
ASC_ATL = Beta('ASC_ATL ', 0, -100, 100, 0)
ASC_COR = Beta('ASC_COR ', 0, -100, 100, 0)
ASC_GIA = Beta('ASC_GIA ', 0, -100, 100, 0)
ASC_PAR = Beta('ASC_PAR ', 0, -100, 100, 0)
ASC_ESP = Beta('ASC_ESP ', 0, -100, 100, 1)
ASC_ORN = Beta('ASC_ORN ', 0, -100, 100, 0)
ASC_PIZ = Beta('ASC_PIZ ', 0, -100, 100, 0)
ASC_KEB = Beta('ASC_KEB ', 0, -100, 100, 0)
ASC_SAT = Beta('ASC_SAT ', 0, -100, 100, 0)
ASC_HOD = Beta('ASC_HOD ', 0, -100, 100, 0)
ASC_VAL = Beta('ASC_VAL ', 0, -100, 100, 0)
ASC_INM = Beta('ASC_INM ', 0, -100, 100, 0)
ASC_VIN = Beta('ASC_VIN', 0, -100, 100, 0)
ASC_COP = Beta('ASC_COP', 0, -100, 100, 0)
ASC_KLE = Beta('ASC_KLE', 0, -100, 100, 0)
ASC_ARC = Beta('ASC_ARC', 0, -100, 100, 0)
BETA_PRICE = Beta('BETA_PRICE', 0, -100, 100, 0)
BETA_DINNER = Beta('BETA_DINNER', 0, -100, 100, 0)

# %%
BETA_DISTANCE = Beta('BETA_DISTANCE',0, -100, 100, 0)
BETA_NO_DISTANCE_AV = Beta('BETA_NO_DISTANCE_AV', 0, -100, 100, 0)

# %%
one = 1
lunch11 = ((H_START == 11) * (M_START > 29.9)) > 0
lunch12 = H_START == 12
lunch13 = H_START == 13
dinner18 = H_START == 18
dinner19 = H_START == 19
morning7 = H_START == 7
morning8 = H_START == 8
morning9 = H_START == 9
morning10 = H_START == 10
morning11 = ((H_START == 11) * (M_START < 29.8)) > 0
afternoon14 = H_START == 14
afternoon15 = H_START == 15
afternoon16 = H_START == 16
afternoon17 = H_START == 17
night20 = H_START == 20
night21 = H_START == 21
night_end21 = H_END == 21
night_end22 = H_END == 22
night = (night20 + night21 + night_end21 + night_end22) > 0
afternoon = (afternoon15 + afternoon16 + afternoon17 + afternoon14) > 0
morning = (morning8 + morning9 + morning10 + morning7 + morning11) > 0
dinner = (dinner18 + dinner19) > 0
lunch = (lunch11 + lunch12 + lunch13) > 0
first_year = SEMESTER == 2
after_lunch = (afternoon + night + dinner) > 0
self_true = SELF == 1
restaurant_true = RESTAURANT == 1
caravan_true = CARAVAN == 1
cafet_true = CAFETERIA == 1
rain_and_cold_max_20 = SUN_AND_HEAT_MIN_20 == 0
perso = SECTION_ID == 5
student_true = STUDENT == 1
self_cafet = (cafet_true + self_true + caravan_true + restaurant_true) > 0

distance_filter_1 = DISTANCE_1 > -1
distance_filter_2 = DISTANCE_2 > -1
distance_filter_3 = DISTANCE_3 > -1
distance_filter_4 = DISTANCE_4 > -1
distance_filter_5 = DISTANCE_5 > -1
distance_filter_6 = DISTANCE_6 > -1
distance_filter_7 = DISTANCE_7 > -1
distance_filter_8 = DISTANCE_8 > -1
distance_filter_9 = DISTANCE_9 > -1
distance_filter_10 = DISTANCE_10 > -1
distance_filter_11 = DISTANCE_11 > -1
distance_filter_12 = DISTANCE_12 > -1
distance_filter_13 = DISTANCE_13 > -1
distance_filter_14 = DISTANCE_14 > -1
distance_filter_15 = DISTANCE_15 > -1
distance_filter_16 = DISTANCE_16 > -1
distance_filter_17 = DISTANCE_17 > -1
distance_filter_18 = DISTANCE_18 > -1
distance_filter_19 = DISTANCE_19 > -1
distance_filter_20 = DISTANCE_20 > -1
distance_filter_21 = DISTANCE_21 > -1
distance_no_av_1 = DISTANCE_1 == -1
distance_no_av_2 = DISTANCE_2 == -1
distance_no_av_3 = DISTANCE_3 == -1
distance_no_av_4 = DISTANCE_4 == -1
distance_no_av_5 = DISTANCE_5 == -1
distance_no_av_6 = DISTANCE_6 == -1
distance_no_av_7 = DISTANCE_7 == -1
distance_no_av_8 = DISTANCE_8 == -1
distance_no_av_9 = DISTANCE_9 == -1
distance_no_av_10 = DISTANCE_10 == -1
distance_no_av_11 = DISTANCE_11 == -1
distance_no_av_12 = DISTANCE_12 == -1
distance_no_av_13 = DISTANCE_13 == -1
distance_no_av_14 = DISTANCE_14 == -1
distance_no_av_15 = DISTANCE_15 == -1
distance_no_av_16 = DISTANCE_16 == -1
distance_no_av_17 = DISTANCE_17 == -1
distance_no_av_18 = DISTANCE_18 == -1
distance_no_av_19 = DISTANCE_19 == -1
distance_no_av_20 = DISTANCE_20 == -1
distance_no_av_21 = DISTANCE_21 == -1

lunch_hot_meal_av_1 = lunch * HOT_MEAL_AV_1
lunch_hot_meal_av_2 = lunch * HOT_MEAL_AV_2
lunch_hot_meal_av_3 = lunch * HOT_MEAL_AV_3
lunch_hot_meal_av_4 = lunch * HOT_MEAL_AV_4
lunch_hot_meal_av_5 = lunch * HOT_MEAL_AV_5
lunch_hot_meal_av_6 = lunch * HOT_MEAL_AV_6
lunch_hot_meal_av_7 = lunch * HOT_MEAL_AV_7
lunch_hot_meal_av_8 = lunch * HOT_MEAL_AV_8
lunch_hot_meal_av_9 = lunch * HOT_MEAL_AV_9
lunch_hot_meal_av_10 = lunch * HOT_MEAL_AV_10
lunch_hot_meal_av_11 = lunch * HOT_MEAL_AV_11
lunch_hot_meal_av_12 = lunch * HOT_MEAL_AV_12
lunch_hot_meal_av_13 = lunch * HOT_MEAL_AV_13
lunch_hot_meal_av_14 = lunch * HOT_MEAL_AV_14
lunch_hot_meal_av_15 = lunch * HOT_MEAL_AV_15
lunch_hot_meal_av_16 = lunch * HOT_MEAL_AV_16
lunch_hot_meal_av_17 = lunch * HOT_MEAL_AV_17
lunch_hot_meal_av_18 = lunch * HOT_MEAL_AV_18
lunch_hot_meal_av_19 = lunch * HOT_MEAL_AV_19
lunch_hot_meal_av_20 = lunch * HOT_MEAL_AV_20
lunch_hot_meal_av_21 = lunch * HOT_MEAL_AV_21

capacity_at_lunch_inside_av_1 = lunch * CAPACITY_INSIDE_1
capacity_at_lunch_inside_av_2 = lunch * CAPACITY_INSIDE_2
capacity_at_lunch_inside_av_3 = lunch * CAPACITY_INSIDE_3
capacity_at_lunch_inside_av_4 = lunch * CAPACITY_INSIDE_4
capacity_at_lunch_inside_av_5 = lunch * CAPACITY_INSIDE_5
capacity_at_lunch_inside_av_6 = lunch * CAPACITY_INSIDE_6
capacity_at_lunch_inside_av_7 = lunch * CAPACITY_INSIDE_7
capacity_at_lunch_inside_av_8 = lunch * CAPACITY_INSIDE_8
capacity_at_lunch_inside_av_9 = lunch * CAPACITY_INSIDE_9
capacity_at_lunch_inside_av_10 = lunch * CAPACITY_INSIDE_10
capacity_at_lunch_inside_av_11 = lunch * CAPACITY_INSIDE_11
capacity_at_lunch_inside_av_12 = lunch * CAPACITY_INSIDE_12
capacity_at_lunch_inside_av_13 = lunch * CAPACITY_INSIDE_13
capacity_at_lunch_inside_av_14 = lunch * CAPACITY_INSIDE_14
capacity_at_lunch_inside_av_15 = lunch * CAPACITY_INSIDE_15
capacity_at_lunch_inside_av_16 = lunch * CAPACITY_INSIDE_16
capacity_at_lunch_inside_av_17 = lunch * CAPACITY_INSIDE_17
capacity_at_lunch_inside_av_18 = lunch * CAPACITY_INSIDE_18
capacity_at_lunch_inside_av_19 = lunch * CAPACITY_INSIDE_19
capacity_at_lunch_inside_av_20 = lunch * CAPACITY_INSIDE_20
capacity_at_lunch_inside_av_21 = lunch * CAPACITY_INSIDE_21


capacity_at_lunch_outside_av_1 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_1
capacity_at_lunch_outside_av_2 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_2
capacity_at_lunch_outside_av_3 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_3
capacity_at_lunch_outside_av_4 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_4
capacity_at_lunch_outside_av_5 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_5
capacity_at_lunch_outside_av_6 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_6
capacity_at_lunch_outside_av_7 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_7
capacity_at_lunch_outside_av_8 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_8
capacity_at_lunch_outside_av_9 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_9
capacity_at_lunch_outside_av_10 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_10
capacity_at_lunch_outside_av_11 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_11
capacity_at_lunch_outside_av_12 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_12
capacity_at_lunch_outside_av_13 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_13
capacity_at_lunch_outside_av_14 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_14
capacity_at_lunch_outside_av_15 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_15
capacity_at_lunch_outside_av_16 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_16
capacity_at_lunch_outside_av_17 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_17
capacity_at_lunch_outside_av_18 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_18
capacity_at_lunch_outside_av_19 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_19
capacity_at_lunch_outside_av_20 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_20
capacity_at_lunch_outside_av_21 = SUN_AND_HEAT_MIN_20 * lunch * CAPACITY_OUTSIDE_21

sandwich_lunch_av_1 = lunch * SANDWICH_AV_1
sandwich_lunch_av_2 = lunch * SANDWICH_AV_2
sandwich_lunch_av_3 = lunch * SANDWICH_AV_3
sandwich_lunch_av_4 = lunch * SANDWICH_AV_4
sandwich_lunch_av_5 = lunch * SANDWICH_AV_5
sandwich_lunch_av_6 = lunch * SANDWICH_AV_6
sandwich_lunch_av_7 = lunch * SANDWICH_AV_7
sandwich_lunch_av_8 = lunch * SANDWICH_AV_8
sandwich_lunch_av_9 = lunch * SANDWICH_AV_9
sandwich_lunch_av_10 = lunch * SANDWICH_AV_10
sandwich_lunch_av_11 = lunch * SANDWICH_AV_11
sandwich_lunch_av_12 = lunch * SANDWICH_AV_12
sandwich_lunch_av_13 = lunch * SANDWICH_AV_13
sandwich_lunch_av_14 = lunch * SANDWICH_AV_14
sandwich_lunch_av_15 = lunch * SANDWICH_AV_15
sandwich_lunch_av_16 = lunch * SANDWICH_AV_16
sandwich_lunch_av_17 = lunch * SANDWICH_AV_17
sandwich_lunch_av_18 = lunch * SANDWICH_AV_18
sandwich_lunch_av_19 = lunch * SANDWICH_AV_19
sandwich_lunch_av_20 = lunch * SANDWICH_AV_20
sandwich_lunch_av_21 = lunch * SANDWICH_AV_21
evaluation_filter_1 = EVALUATION_2013_1 > -1
evaluation_filter_2 = EVALUATION_2013_2 > -1
evaluation_filter_3 = EVALUATION_2013_3 > -1
evaluation_filter_4 = EVALUATION_2013_4 > -1
evaluation_filter_5 = EVALUATION_2013_5 > -1
evaluation_filter_6 = EVALUATION_2013_6 > -1
evaluation_filter_7 = EVALUATION_2013_7 > -1
evaluation_filter_8 = EVALUATION_2013_8 > -1
evaluation_filter_9 = EVALUATION_2013_9 > -1
evaluation_filter_10 = EVALUATION_2013_10 > -1
evaluation_filter_11 = EVALUATION_2013_11 > -1
evaluation_filter_12 = EVALUATION_2013_12 > -1
evaluation_filter_13 = EVALUATION_2013_13 > -1
evaluation_filter_14 = EVALUATION_2013_14 > -1
evaluation_filter_15 = EVALUATION_2013_15 > -1
evaluation_filter_16 = EVALUATION_2013_16 > -1
evaluation_filter_17 = EVALUATION_2013_17 > -1
evaluation_filter_18 = EVALUATION_2013_18 > -1
evaluation_filter_19 = EVALUATION_2013_19 > -1
evaluation_filter_20 = EVALUATION_2013_20 > -1
evaluation_filter_21 = EVALUATION_2013_21 > -1
evaluation_2013_self_1 = ((evaluation_filter_1 * EVALUATION_2013_1) * self_true) * lunch
evaluation_2013_self_2 = ((evaluation_filter_2 * EVALUATION_2013_2) * self_true) * lunch
evaluation_2013_self_3 = ((evaluation_filter_3 * EVALUATION_2013_3) * self_true) * lunch
evaluation_2013_self_4 = ((evaluation_filter_4 * EVALUATION_2013_4) * self_true) * lunch
evaluation_2013_self_5 = ((evaluation_filter_5 * EVALUATION_2013_5) * self_true) * lunch
evaluation_2013_self_6 = ((evaluation_filter_6 * EVALUATION_2013_6) * self_true) * lunch
evaluation_2013_self_7 = ((evaluation_filter_7 * EVALUATION_2013_7) * self_true) * lunch
evaluation_2013_self_8 = ((evaluation_filter_8 * EVALUATION_2013_8) * self_true) * lunch
evaluation_2013_self_9 = ((evaluation_filter_9 * EVALUATION_2013_9) * self_true) * lunch
evaluation_2013_self_10 = ((evaluation_filter_10 * EVALUATION_2013_10) * self_true) * lunch
evaluation_2013_self_11 = ((evaluation_filter_11 * EVALUATION_2013_11) * self_true) * lunch
evaluation_2013_self_12 = ((evaluation_filter_12 * EVALUATION_2013_12) * self_true) * lunch
evaluation_2013_self_13 = ((evaluation_filter_13 * EVALUATION_2013_13) * self_true) * lunch
evaluation_2013_self_14 = ((evaluation_filter_14 * EVALUATION_2013_14) * self_true) * lunch
evaluation_2013_self_15 = ((evaluation_filter_15 * EVALUATION_2013_15) * self_true) * lunch
evaluation_2013_self_16 = ((evaluation_filter_16 * EVALUATION_2013_16) * self_true) * lunch
evaluation_2013_self_17 = ((evaluation_filter_17 * EVALUATION_2013_17) * self_true) * lunch
evaluation_2013_self_18 = ((evaluation_filter_18 * EVALUATION_2013_18) * self_true) * lunch
evaluation_2013_self_19 = ((evaluation_filter_19 * EVALUATION_2013_19) * self_true) * lunch
evaluation_2013_self_20 = ((evaluation_filter_20 * EVALUATION_2013_20) * self_true) * lunch
evaluation_2013_self_21 = ((evaluation_filter_21 * EVALUATION_2013_21) * self_true) * lunch
evaluation_2013_cafet_1 = ((evaluation_filter_1 * EVALUATION_2013_1) * cafet_true) * lunch
evaluation_2013_cafet_2 = ((evaluation_filter_2 * EVALUATION_2013_2) * cafet_true) * lunch
evaluation_2013_cafet_3 = ((evaluation_filter_3 * EVALUATION_2013_3) * cafet_true) * lunch
evaluation_2013_cafet_4 = ((evaluation_filter_4 * EVALUATION_2013_4) * cafet_true) * lunch
evaluation_2013_cafet_5 = ((evaluation_filter_5 * EVALUATION_2013_5) * cafet_true) * lunch
evaluation_2013_cafet_6 = ((evaluation_filter_6 * EVALUATION_2013_6) * cafet_true) * lunch
evaluation_2013_cafet_7 = ((evaluation_filter_7 * EVALUATION_2013_7) * cafet_true) * lunch
evaluation_2013_cafet_8 = ((evaluation_filter_8 * EVALUATION_2013_8) * cafet_true) * lunch
evaluation_2013_cafet_9 = ((evaluation_filter_9 * EVALUATION_2013_9) * cafet_true) * lunch
evaluation_2013_cafet_10 = ((evaluation_filter_10 * EVALUATION_2013_10) * cafet_true) * lunch
evaluation_2013_cafet_11 = ((evaluation_filter_11 * EVALUATION_2013_11) * cafet_true) * lunch
evaluation_2013_cafet_12 = ((evaluation_filter_12 * EVALUATION_2013_12) * cafet_true) * lunch
evaluation_2013_cafet_13 = ((evaluation_filter_13 * EVALUATION_2013_13) * cafet_true) * lunch
evaluation_2013_cafet_14 = ((evaluation_filter_14 * EVALUATION_2013_14) * cafet_true) * lunch
evaluation_2013_cafet_15 = ((evaluation_filter_15 * EVALUATION_2013_15) * cafet_true) * lunch
evaluation_2013_cafet_16 = ((evaluation_filter_16 * EVALUATION_2013_16) * cafet_true) * lunch
evaluation_2013_cafet_17 = ((evaluation_filter_17 * EVALUATION_2013_17) * cafet_true) * lunch
evaluation_2013_cafet_18 = ((evaluation_filter_18 * EVALUATION_2013_18) * cafet_true) * lunch
evaluation_2013_cafet_19 = ((evaluation_filter_19 * EVALUATION_2013_19) * cafet_true) * lunch
evaluation_2013_cafet_20 = ((evaluation_filter_20 * EVALUATION_2013_20) * cafet_true) * lunch
evaluation_2013_cafet_21 = ((evaluation_filter_21 * EVALUATION_2013_21) * cafet_true) * lunch
evaluation_2013_self_cafet_1 = ((evaluation_filter_1 * EVALUATION_2013_1) * self_cafet) * lunch
evaluation_2013_self_cafet_2 = ((evaluation_filter_2 * EVALUATION_2013_2) * self_cafet) * lunch
evaluation_2013_self_cafet_3 = ((evaluation_filter_3 * EVALUATION_2013_3) * self_cafet) * lunch
evaluation_2013_self_cafet_4 = ((evaluation_filter_4 * EVALUATION_2013_4) * self_cafet) * lunch
evaluation_2013_self_cafet_5 = ((evaluation_filter_5 * EVALUATION_2013_5) * self_cafet) * lunch
evaluation_2013_self_cafet_6 = ((evaluation_filter_6 * EVALUATION_2013_6) * self_cafet) * lunch
evaluation_2013_self_cafet_7 = ((evaluation_filter_7 * EVALUATION_2013_7) * self_cafet) * lunch
evaluation_2013_self_cafet_8 = ((evaluation_filter_8 * EVALUATION_2013_8) * self_cafet) * lunch
evaluation_2013_self_cafet_9 = ((evaluation_filter_9 * EVALUATION_2013_9) * self_cafet) * lunch
evaluation_2013_self_cafet_10 = ((evaluation_filter_10 * EVALUATION_2013_10) * self_cafet) * lunch
evaluation_2013_self_cafet_11 = ((evaluation_filter_11 * EVALUATION_2013_11) * self_cafet) * lunch
evaluation_2013_self_cafet_12 = ((evaluation_filter_12 * EVALUATION_2013_12) * self_cafet) * lunch
evaluation_2013_self_cafet_13 = ((evaluation_filter_13 * EVALUATION_2013_13) * self_cafet) * lunch
evaluation_2013_self_cafet_14 = ((evaluation_filter_14 * EVALUATION_2013_14) * self_cafet) * lunch
evaluation_2013_self_cafet_15 = ((evaluation_filter_15 * EVALUATION_2013_15) * self_cafet) * lunch
evaluation_2013_self_cafet_16 = ((evaluation_filter_16 * EVALUATION_2013_16) * self_cafet) * lunch
evaluation_2013_self_cafet_17 = ((evaluation_filter_17 * EVALUATION_2013_17) * self_cafet) * lunch
evaluation_2013_self_cafet_18 = ((evaluation_filter_18 * EVALUATION_2013_18) * self_cafet) * lunch
evaluation_2013_self_cafet_19 = ((evaluation_filter_19 * EVALUATION_2013_19) * self_cafet) * lunch
evaluation_2013_self_cafet_20 = ((evaluation_filter_20 * EVALUATION_2013_20) * self_cafet) * lunch
evaluation_2013_self_cafet_21 = ((evaluation_filter_21 * EVALUATION_2013_21) * self_cafet) * lunch
dinner_av_1 = DINNER_HOT_MEAL_AV_1 * dinner
dinner_av_2 = DINNER_HOT_MEAL_AV_2 * dinner
dinner_av_3 = DINNER_HOT_MEAL_AV_3 * dinner
dinner_av_4 = DINNER_HOT_MEAL_AV_4 * dinner
dinner_av_5 = DINNER_HOT_MEAL_AV_5 * dinner
dinner_av_6 = DINNER_HOT_MEAL_AV_6 * dinner
dinner_av_7 = DINNER_HOT_MEAL_AV_7 * dinner
dinner_av_8 = DINNER_HOT_MEAL_AV_8 * dinner
dinner_av_9 = DINNER_HOT_MEAL_AV_9 * dinner
dinner_av_10 = DINNER_HOT_MEAL_AV_10 * dinner
dinner_av_11 = DINNER_HOT_MEAL_AV_11 * dinner
dinner_av_12 = DINNER_HOT_MEAL_AV_12 * dinner
dinner_av_13 = DINNER_HOT_MEAL_AV_13 * dinner
dinner_av_14 = DINNER_HOT_MEAL_AV_14 * dinner
dinner_av_15 = DINNER_HOT_MEAL_AV_15 * dinner
dinner_av_16 = DINNER_HOT_MEAL_AV_16 * dinner
dinner_av_17 = DINNER_HOT_MEAL_AV_17 * dinner
dinner_av_18 = DINNER_HOT_MEAL_AV_18 * dinner
dinner_av_19 = DINNER_HOT_MEAL_AV_19 * dinner
dinner_av_20 = DINNER_HOT_MEAL_AV_20 * dinner
dinner_av_21 = DINNER_HOT_MEAL_AV_21 * dinner
lunch_price_min_student_1 = (lunch * MIN_PRICE_1) * student_true
lunch_price_min_student_2 = (lunch * MIN_PRICE_2) * student_true
lunch_price_min_student_3 = (lunch * MIN_PRICE_3) * student_true
lunch_price_min_student_4 = (lunch * MIN_PRICE_4) * student_true
lunch_price_min_student_5 = (lunch * MIN_PRICE_5) * student_true
lunch_price_min_student_6 = (lunch * MIN_PRICE_6) * student_true
lunch_price_min_student_7 = (lunch * MIN_PRICE_7) * student_true
lunch_price_min_student_8 = (lunch * MIN_PRICE_8) * student_true
lunch_price_min_student_9 = (lunch * MIN_PRICE_9) * student_true
lunch_price_min_student_10 = (lunch * MIN_PRICE_10) * student_true
lunch_price_min_student_11 = (lunch * MIN_PRICE_11) * student_true
lunch_price_min_student_12 = (lunch * MIN_PRICE_12) * student_true
lunch_price_min_student_13 = (lunch * MIN_PRICE_13) * student_true
lunch_price_min_student_14 = (lunch * MIN_PRICE_14) * student_true
lunch_price_min_student_15 = (lunch * MIN_PRICE_15) * student_true
lunch_price_min_student_16 = (lunch * MIN_PRICE_16) * student_true
lunch_price_min_student_17 = (lunch * MIN_PRICE_17) * student_true
lunch_price_min_student_18 = (lunch * MIN_PRICE_18) * student_true
lunch_price_min_student_19 = (lunch * MIN_PRICE_19) * student_true
lunch_price_min_student_20 = (lunch * MIN_PRICE_20) * student_true
lunch_price_min_student_21 = (lunch * MIN_PRICE_21) * student_true
lunch_price_min_employee_1 = (lunch * MIN_PRICE_1) * perso
lunch_price_min_employee_2 = (lunch * MIN_PRICE_2) * perso
lunch_price_min_employee_3 = (lunch * MIN_PRICE_3) * perso
lunch_price_min_employee_4 = (lunch * MIN_PRICE_4) * perso
lunch_price_min_employee_5 = (lunch * MIN_PRICE_5) * perso
lunch_price_min_employee_6 = (lunch * MIN_PRICE_6) * perso
lunch_price_min_employee_7 = (lunch * MIN_PRICE_7) * perso
lunch_price_min_employee_8 = (lunch * MIN_PRICE_8) * perso
lunch_price_min_employee_9 = (lunch * MIN_PRICE_9) * perso
lunch_price_min_employee_10 = (lunch * MIN_PRICE_10) * perso
lunch_price_min_employee_11 = (lunch * MIN_PRICE_11) * perso
lunch_price_min_employee_12 = (lunch * MIN_PRICE_12) * perso
lunch_price_min_employee_13 = (lunch * MIN_PRICE_13) * perso
lunch_price_min_employee_14 = (lunch * MIN_PRICE_14) * perso
lunch_price_min_employee_15 = (lunch * MIN_PRICE_15) * perso
lunch_price_min_employee_16 = (lunch * MIN_PRICE_16) * perso
lunch_price_min_employee_17 = (lunch * MIN_PRICE_17) * perso
lunch_price_min_employee_18 = (lunch * MIN_PRICE_18) * perso
lunch_price_min_employee_19 = (lunch * MIN_PRICE_19) * perso
lunch_price_min_employee_20 = (lunch * MIN_PRICE_20) * perso
lunch_price_min_employee_21 = (lunch * MIN_PRICE_21) * perso

# %%
lunch_price_min_1 = lunch * MIN_PRICE_1
lunch_price_min_2 = lunch * MIN_PRICE_2
lunch_price_min_3 = lunch * MIN_PRICE_3
lunch_price_min_4 = lunch * MIN_PRICE_4
lunch_price_min_5 = lunch * MIN_PRICE_5
lunch_price_min_6 = lunch * MIN_PRICE_6
lunch_price_min_7 = lunch * MIN_PRICE_7
lunch_price_min_8 = lunch * MIN_PRICE_8
lunch_price_min_9 = lunch * MIN_PRICE_9
lunch_price_min_10 = lunch * MIN_PRICE_10
lunch_price_min_11 = lunch * MIN_PRICE_11
lunch_price_min_12 = lunch * MIN_PRICE_12
lunch_price_min_13 = lunch * MIN_PRICE_13
lunch_price_min_14 = lunch * MIN_PRICE_14
lunch_price_min_15 = lunch * MIN_PRICE_15
lunch_price_min_16 = lunch * MIN_PRICE_16
lunch_price_min_17 = lunch * MIN_PRICE_17
lunch_price_min_18 = lunch * MIN_PRICE_18
lunch_price_min_19 = lunch * MIN_PRICE_19
lunch_price_min_20 = lunch * MIN_PRICE_20
lunch_price_min_21 = lunch * MIN_PRICE_21

# %%
distance_1 = distance_filter_1 * DISTANCE_1 / 100
distance_2 = distance_filter_2 * DISTANCE_2 / 100
distance_3 = distance_filter_3 * DISTANCE_3 / 100
distance_4 = distance_filter_4 * DISTANCE_4 / 100
distance_5 = distance_filter_5 * DISTANCE_5 / 100
distance_6 = distance_filter_6 * DISTANCE_6 / 100
distance_7 = distance_filter_7 * DISTANCE_7 / 100
distance_8 = distance_filter_8 * DISTANCE_8 / 100
distance_9 = distance_filter_9 * DISTANCE_9 / 100
distance_10 = distance_filter_10 * DISTANCE_10 / 100
distance_11 = distance_filter_11 * DISTANCE_11 / 100
distance_12 = distance_filter_12 * DISTANCE_12 / 100
distance_13 = distance_filter_13 * DISTANCE_13 / 100
distance_14 = distance_filter_14 * DISTANCE_14 / 100
distance_15 = distance_filter_15 * DISTANCE_15 / 100
distance_16 = distance_filter_16 * DISTANCE_16 / 100
distance_17 = distance_filter_17 * DISTANCE_17 / 100
distance_18 = distance_filter_18 * DISTANCE_18 / 100
distance_19 = distance_filter_19 * DISTANCE_19 / 100
distance_20 = distance_filter_20 * DISTANCE_20 / 100
distance_21 = distance_filter_21 * DISTANCE_21 / 100

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}

# %%
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_1"

# %%
results_1 = biogeme.estimate()

# %%
print(results_1)
# Out:
# Results for model [my model_1]
# Output file (HTML):			my model_1.html
# Nbr of parameters:		22
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-4070.29
# Likelihood ratio test:		1935.247
# Rho square:			0.192
# Rho bar square:			0.188
# Akaike Information Criterion:	8184.581
# Bayesian Information Criterion:	8306.299
# Final gradient norm:		0.0554357
# ASC_ARC        : -2.13[0.282 -7.57 3.8e-14][0.281 -7.58 3.51e-14]
# ASC_ATL        : -0.986[0.236 -4.18 2.95e-05][0.234 -4.22 2.5e-05]
# ASC_BC         : -0.386[0.103 -3.76 0.000173][0.102 -3.77 0.000163]
# ASC_BM         : -1.89[0.78 -2.42 0.0155][0.785 -2.4 0.0162]
# ASC_COP        : -3.47[1.16 -2.98 0.0029][1.17 -2.97 0.00295]
# ASC_COR        : -0.363[0.136 -2.67 0.00758][0.138 -2.63 0.00846]
# ASC_ELA        : -0.738[0.217 -3.4 0.000673][0.235 -3.15 0.00165]
# ASC_GIA        : -0.477[0.189 -2.53 0.0115][0.196 -2.43 0.015]
# ...

# %% [markdown]
# Now think of the price, we can see from the data that some of the min_price is 0, which means the catering location will not provide meal for lunch or dinner. So as for the lunch price, these places will not be more attractive than the places that offer food.
#
# This should be taken into consideration.

# %%
price_filter_1 = MIN_PRICE_1 > 0
price_filter_2 = MIN_PRICE_2 > 0
price_filter_3 = MIN_PRICE_3 > 0
price_filter_4 = MIN_PRICE_4 > 0
price_filter_5 = MIN_PRICE_5 > 0
price_filter_6 = MIN_PRICE_6 > 0
price_filter_7 = MIN_PRICE_7 > 0
price_filter_8 = MIN_PRICE_7 > 0
price_filter_9 = MIN_PRICE_9 > 0
price_filter_10 = MIN_PRICE_10 > 0
price_filter_11 = MIN_PRICE_11 > 0
price_filter_12 = MIN_PRICE_12 > 0
price_filter_13 = MIN_PRICE_13 > 0
price_filter_14 = MIN_PRICE_14 > 0
price_filter_15 = MIN_PRICE_15 > 0
price_filter_16 = MIN_PRICE_16 > 0
price_filter_17 = MIN_PRICE_17 > 0
price_filter_18 = MIN_PRICE_18 > 0
price_filter_19 = MIN_PRICE_19 > 0
price_filter_20 = MIN_PRICE_20 > 0
price_filter_21 = MIN_PRICE_21 > 0
no_meal_1 = 1 - price_filter_1 
no_meal_2 = 1 - price_filter_2 
no_meal_3 = 1 - price_filter_3 
no_meal_4 = 1 - price_filter_4 
no_meal_5 = 1 - price_filter_5 
no_meal_6 = 1 - price_filter_6 
no_meal_7 = 1 - price_filter_7 
no_meal_8 = 1 - price_filter_8 
no_meal_9 = 1 - price_filter_9 
no_meal_10 = 1 - price_filter_10
no_meal_11 = 1 - price_filter_11 
no_meal_12 = 1 - price_filter_12 
no_meal_13 = 1 - price_filter_13 
no_meal_14 = 1 - price_filter_14 
no_meal_15 = 1 - price_filter_15 
no_meal_16 = 1 - price_filter_16 
no_meal_17 = 1 - price_filter_17 
no_meal_18 = 1 - price_filter_18 
no_meal_19 = 1 - price_filter_19 
no_meal_20 = 1 - price_filter_20 
no_meal_21 = 1 - price_filter_21

# %%
BETA_NO_MEAL = Beta('BETA_NO_MEAL', 0, -100, 100, 0)

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_NO_MEAL * no_meal_3\

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_NO_MEAL * no_meal_7\

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}

# %%
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_2"

# %%
results_2 = biogeme.estimate()

# %%
print(results_2)
# Out:
# Results for model [my model_2]
# Output file (HTML):			my model_2~00.html
# Nbr of parameters:		23
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-4070.291
# Likelihood ratio test:		1935.247
# Rho square:			0.192
# Rho bar square:			0.188
# Akaike Information Criterion:	8186.581
# Bayesian Information Criterion:	8313.832
# Final gradient norm:		0.1050199
# ASC_ARC        : -0.837[0.565 -1.48 0.138][0.565 -1.48 0.138]
# ASC_ATL        : -0.988[0.236 -4.19 2.8e-05][0.234 -4.23 2.37e-05]
# ASC_BC         : -0.386[0.103 -3.76 0.000172][0.102 -3.77 0.000162]
# ASC_BM         : -0.579[0.454 -1.27 0.203][0.461 -1.26 0.209]
# ASC_COP        : -3.48[1.16 -2.99 0.0028][1.17 -2.98 0.00284]
# ASC_COR        : -0.363[0.136 -2.67 0.00749][0.138 -2.64 0.00836]
# ASC_ELA        : -0.736[0.217 -3.39 0.000701][0.235 -3.14 0.00171]
# ASC_GIA        : -0.475[0.189 -2.52 0.0119][0.196 -2.42 0.0154]
# ...

# %% [markdown]
# It is clear that model_2 makes no improvement. What if compared with price, people focus more on the quality of food?

# %%
BETA_EVA = Beta('BETA_EVA', 0, -100, 100, 0)

# %%
eva_1 = evaluation_filter_1 * EVALUATION_2013_1
eva_2 = evaluation_filter_2 * EVALUATION_2013_2
eva_3 = evaluation_filter_3 * EVALUATION_2013_3
eva_4 = evaluation_filter_4 * EVALUATION_2013_4
eva_5 = evaluation_filter_5 * EVALUATION_2013_5
eva_6 = evaluation_filter_6 * EVALUATION_2013_6
eva_7 = evaluation_filter_7 * EVALUATION_2013_7
eva_8 = evaluation_filter_8 * EVALUATION_2013_8
eva_9 = evaluation_filter_9 * EVALUATION_2013_9
eva_10 = evaluation_filter_10 * EVALUATION_2013_10
eva_11 = evaluation_filter_11 * EVALUATION_2013_11
eva_12 = evaluation_filter_12 * EVALUATION_2013_12
eva_13 = evaluation_filter_13 * EVALUATION_2013_13
eva_14 = evaluation_filter_14 * EVALUATION_2013_14
eva_15 = evaluation_filter_15 * EVALUATION_2013_15
eva_16 = evaluation_filter_16 * EVALUATION_2013_16
eva_17 = evaluation_filter_17 * EVALUATION_2013_17
eva_18 = evaluation_filter_18 * EVALUATION_2013_18
eva_19 = evaluation_filter_19 * EVALUATION_2013_19
eva_20 = evaluation_filter_20 * EVALUATION_2013_20
eva_21 = evaluation_filter_21 * EVALUATION_2013_21

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 \
    + BETA_EVA * eva_1\

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 \
    + BETA_EVA * eva_2\

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 \
    + BETA_EVA * eva_4\

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 \
    + BETA_EVA * eva_5\

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 \
    + BETA_EVA * eva_6\

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 \
    + BETA_EVA * eva_8\

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 \
    + BETA_EVA * eva_9\

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 \
    + BETA_EVA * eva_10\

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 \
    + BETA_EVA * eva_11\

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 \
    + BETA_EVA * eva_12\

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 \
    + BETA_EVA * eva_13\

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 \
    + BETA_EVA * eva_14\

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 \
    + BETA_EVA * eva_15\

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 \
    + BETA_EVA * eva_16\

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 \
    + BETA_EVA * eva_17\

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 \
    + BETA_EVA * eva_18\

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 \
    + BETA_EVA * eva_19\

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 \
    + BETA_EVA * eva_20\

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 \
    + BETA_EVA * eva_21\

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}

# %%
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_3"

# %%
results_3 = biogeme.estimate()

# %%
print(results_3)
# Out:
# Results for model [my model_3]
# Output file (HTML):			my model_3.html
# Nbr of parameters:		23
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-4070.291
# Likelihood ratio test:		1935.246
# Rho square:			0.192
# Rho bar square:			0.188
# Akaike Information Criterion:	8186.581
# Bayesian Information Criterion:	8313.832
# Final gradient norm:		0.07772653
# ASC_ARC        : -2.14[0.247 -8.67 0][0.247 -8.68 0]
# ASC_ATL        : -1[0.176 -5.71 1.14e-08][0.174 -5.77 8.13e-09]
# ASC_BC         : -0.411[0.122 -3.38 0.000728][0.13 -3.16 0.00156]
# ASC_BM         : -1.57[0.188 -8.35 0][0.179 -8.79 0]
# ASC_COP        : -3.48[1.03 -3.38 0.00072][1.03 -3.37 0.000746]
# ASC_COR        : -0.366[0.136 -2.69 0.00719][0.139 -2.64 0.0083]
# ASC_ELA        : -0.8[0.356 -2.25 0.0244][0.373 -2.14 0.0321]
# ASC_GIA        : -0.483[0.191 -2.54 0.0112][0.198 -2.44 0.0146]
# ASC_HOD        : -1.3[0.673 -1.94 0.0529][0.641 -2.03 0.0422]
# ...

# %% [markdown]
# Perhaps meal hot or not matters?

# %%
BETA_HOT = Beta('BETA_HOT', 0, -100, 100, 0)

# %%
hot_av_1 = lunch_hot_meal_av_1 + dinner_av_1
hot_av_2 = lunch_hot_meal_av_2 + dinner_av_2
hot_av_3 = lunch_hot_meal_av_3 + dinner_av_3
hot_av_4 = lunch_hot_meal_av_4 + dinner_av_4
hot_av_5 = lunch_hot_meal_av_5 + dinner_av_5
hot_av_6 = lunch_hot_meal_av_6 + dinner_av_6
hot_av_7 = lunch_hot_meal_av_7 + dinner_av_7
hot_av_8 = lunch_hot_meal_av_8 + dinner_av_8
hot_av_9 = lunch_hot_meal_av_9 + dinner_av_9
hot_av_10 = lunch_hot_meal_av_10 + dinner_av_10
hot_av_11 = lunch_hot_meal_av_11 + dinner_av_11
hot_av_12 = lunch_hot_meal_av_12 + dinner_av_12
hot_av_13 = lunch_hot_meal_av_13 + dinner_av_13
hot_av_14 = lunch_hot_meal_av_14 + dinner_av_14
hot_av_15 = lunch_hot_meal_av_15 + dinner_av_15
hot_av_16 = lunch_hot_meal_av_16 + dinner_av_16
hot_av_17 = lunch_hot_meal_av_17 + dinner_av_17
hot_av_18 = lunch_hot_meal_av_18 + dinner_av_18
hot_av_19 = lunch_hot_meal_av_19 + dinner_av_19
hot_av_20 = lunch_hot_meal_av_20 + dinner_av_20
hot_av_21 = lunch_hot_meal_av_21 + dinner_av_21

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * hot_av_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * hot_av_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * hot_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * hot_av_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * hot_av_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * hot_av_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * hot_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * hot_av_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * hot_av_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * hot_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * hot_av_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * hot_av_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * hot_av_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * hot_av_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * hot_av_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * hot_av_16 \


V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * hot_av_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * hot_av_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * hot_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * hot_av_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * hot_av_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}

# %%
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_4"

# %%
results_4 =biogeme.estimate()

# %%
print(results_4)
# Out:
# Results for model [my model_4]
# Output file (HTML):			my model_4.html
# Nbr of parameters:		22
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-4064.828
# Likelihood ratio test:		1946.172
# Rho square:			0.193
# Rho bar square:			0.189
# Akaike Information Criterion:	8173.656
# Bayesian Information Criterion:	8295.373
# Final gradient norm:		0.1434525
# ASC_ARC        : -2.03[0.172 -11.8 0][0.17 -11.9 0]
# ASC_ATL        : -0.892[0.102 -8.76 0][0.102 -8.76 0]
# ASC_BC         : -0.381[0.103 -3.7 0.000213][0.103 -3.71 0.000211]
# ASC_BM         : -2.2[0.162 -13.5 0][0.164 -13.4 0]
# ASC_COP        : -3.39[0.445 -7.62 2.6e-14][0.442 -7.67 1.75e-14]
# ASC_COR        : -0.432[0.137 -3.16 0.0016][0.138 -3.13 0.00177]
# ASC_ELA        : -0.737[0.109 -6.76 1.37e-11][0.107 -6.86 6.79e-12]
# ASC_GIA        : -0.466[0.0965 -4.83 1.36e-06][0.0938 -4.97 6.75e-07]
# ASC_HOD        : -1.31[0.213 -6.16 7.07e-10][0.206 -6.38 1.82e-10]
# ...

# %% [markdown]
# The sign of price is still positive, but now it is significant!

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_5"

# %%
results_5 = biogeme.estimate()

# %%
print(results_5)
# Out:
# Results for model [my model_5]
# Output file (HTML):			my model_5~00.html
# Nbr of parameters:		22
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-4067.235
# Likelihood ratio test:		1941.358
# Rho square:			0.193
# Rho bar square:			0.188
# Akaike Information Criterion:	8178.47
# Bayesian Information Criterion:	8300.188
# Final gradient norm:		0.06524912
# ASC_ARC        : -2.03[0.172 -11.8 0][0.17 -12 0]
# ASC_ATL        : -0.891[0.102 -8.74 0][0.102 -8.72 0]
# ASC_BC         : -0.388[0.103 -3.77 0.000162][0.103 -3.78 0.000157]
# ASC_BM         : -2.25[0.16 -14.1 0][0.162 -13.9 0]
# ASC_COP        : -3.28[0.448 -7.31 2.69e-13][0.446 -7.35 2.05e-13]
# ASC_COR        : -0.419[0.137 -3.05 0.00227][0.139 -3.02 0.00256]
# ASC_ELA        : -0.767[0.109 -7.06 1.65e-12][0.107 -7.19 6.56e-13]
# ASC_GIA        : -0.495[0.096 -5.16 2.5e-07][0.0931 -5.32 1.05e-07]
# ASC_HOD        : -1.24[0.215 -5.75 8.77e-09][0.208 -5.94 2.78e-09]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_DINNER * dinner_av_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_DINNER * dinner_av_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_DINNER * dinner_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_DINNER * dinner_av_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_DINNER * dinner_av_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_DINNER * dinner_av_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_DINNER * dinner_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_DINNER * dinner_av_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_DINNER * dinner_av_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_DINNER * dinner_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_DINNER * dinner_av_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_DINNER * dinner_av_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_DINNER * dinner_av_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_DINNER * dinner_av_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_DINNER * dinner_av_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_DINNER * dinner_av_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_DINNER * dinner_av_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_DINNER * dinner_av_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_DINNER * dinner_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_DINNER * dinner_av_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_DINNER * dinner_av_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_6"

# %%
results_6 = biogeme.estimate()

# %%
print(results_6)
# Out:
# Results for model [my model_6]
# Output file (HTML):			my model_6~00.html
# Nbr of parameters:		23
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-4064.616
# Likelihood ratio test:		1946.597
# Rho square:			0.193
# Rho bar square:			0.189
# Akaike Information Criterion:	8175.231
# Bayesian Information Criterion:	8302.481
# Final gradient norm:		0.0801124
# ASC_ARC        : -2.02[0.172 -11.7 0][0.17 -11.9 0]
# ASC_ATL        : -0.882[0.102 -8.63 0][0.102 -8.61 0]
# ASC_BC         : -0.375[0.103 -3.64 0.000278][0.103 -3.64 0.000277]
# ASC_BM         : -2.18[0.163 -13.4 0][0.164 -13.3 0]
# ASC_COP        : -3.33[0.448 -7.41 1.22e-13][0.446 -7.46 8.64e-14]
# ASC_COR        : -0.42[0.137 -3.06 0.0022][0.139 -3.03 0.00246]
# ASC_ELA        : -0.743[0.109 -6.8 1.02e-11][0.107 -6.91 4.73e-12]
# ASC_GIA        : -0.472[0.0967 -4.88 1.06e-06][0.094 -5.02 5.16e-07]
# ASC_HOD        : -1.27[0.216 -5.88 4.06e-09][0.208 -6.08 1.17e-09]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_7"

# %%
results_7 = biogeme.estimate()

# %%
print(results_7)
# Out:
# Results for model [my model_7]
# Output file (HTML):			my model_7.html
# Nbr of parameters:		23
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3753.117
# Likelihood ratio test:		2569.594
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7552.233
# Bayesian Information Criterion:	7679.484
# Final gradient norm:		0.07959532
# ASC_ARC        : -1.83[0.178 -10.3 0][0.17 -10.8 0]
# ASC_ATL        : -0.755[0.104 -7.29 3.04e-13][0.103 -7.35 1.92e-13]
# ASC_BC         : -0.179[0.111 -1.61 0.108][0.115 -1.56 0.119]
# ASC_BM         : -1.75[0.159 -11 0][0.155 -11.3 0]
# ASC_COP        : -2.88[0.452 -6.36 2.03e-10][0.45 -6.39 1.69e-10]
# ASC_COR        : -0.19[0.141 -1.34 0.179][0.138 -1.37 0.171]
# ASC_ELA        : -0.62[0.11 -5.64 1.74e-08][0.109 -5.69 1.26e-08]
# ASC_GIA        : -0.412[0.0973 -4.23 2.29e-05][0.094 -4.38 1.17e-05]
# ASC_HOD        : -1.07[0.245 -4.36 1.32e-05][0.244 -4.36 1.3e-05]
# ...

# %%
BETA_MICRO = Beta('BETA_MICRO', 0, -100, 100, 0)

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_MICRO * MICROWAVE_AV_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_MICRO * MICROWAVE_AV_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_MICRO * MICROWAVE_AV_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_MICRO * MICROWAVE_AV_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_MICRO * MICROWAVE_AV_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_MICRO * MICROWAVE_AV_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_MICRO * MICROWAVE_AV_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_MICRO * MICROWAVE_AV_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_MICRO * MICROWAVE_AV_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_MICRO * MICROWAVE_AV_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_MICRO * MICROWAVE_AV_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_MICRO * MICROWAVE_AV_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_MICRO * MICROWAVE_AV_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
    + BETA_MICRO * MICROWAVE_AV_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
    + BETA_MICRO * MICROWAVE_AV_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_MICRO * MICROWAVE_AV_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_MICRO * MICROWAVE_AV_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_MICRO * MICROWAVE_AV_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_MICRO * MICROWAVE_AV_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_MICRO * MICROWAVE_AV_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_MICRO * MICROWAVE_AV_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_8"

# %%
results_8 = biogeme.estimate()

# %%
print(results_8)
# Out:
# Results for model [my model_8]
# Output file (HTML):			my model_8.html
# Nbr of parameters:		24
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3753.117
# Likelihood ratio test:		2569.594
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7554.234
# Bayesian Information Criterion:	7687.017
# Final gradient norm:		0.09144013
# ASC_ARC        : -0.459[0.173 -2.65 0.00802][0.17 -2.71 0.00683]
# ASC_ATL        : 0.618[0.12 5.16 2.51e-07][0.109 5.67 1.39e-08]
# ASC_BC         : -0.179[0.111 -1.61 0.108][0.115 -1.56 0.12]
# ASC_BM         : -1.75[0.159 -11 0][0.155 -11.3 0]
# ASC_COP        : -1.5[0.387 -3.89 0.000101][0.386 -3.89 9.83e-05]
# ASC_COR        : 1.18[0.14 8.44 0][0.138 8.56 0]
# ASC_ELA        : -0.619[0.11 -5.63 1.79e-08][0.109 -5.69 1.3e-08]
# ASC_GIA        : -0.412[0.0973 -4.23 2.32e-05][0.094 -4.38 1.19e-05]
# ASC_HOD        : -1.07[0.245 -4.37 1.26e-05][0.245 -4.37 1.26e-05]
# ...

# %%
BETA_BEER = Beta('BETA_BEER', 0, -100, 100, 0)

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_BEER * TAP_BEER_AV_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_BEER * TAP_BEER_AV_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_BEER * TAP_BEER_AV_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_BEER * TAP_BEER_AV_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_BEER * TAP_BEER_AV_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_BEER * TAP_BEER_AV_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_BEER * TAP_BEER_AV_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_BEER * TAP_BEER_AV_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_BEER * TAP_BEER_AV_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_BEER * TAP_BEER_AV_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_BEER * TAP_BEER_AV_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_BEER * TAP_BEER_AV_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_BEER * TAP_BEER_AV_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
    + BETA_BEER * TAP_BEER_AV_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
    + BETA_BEER * TAP_BEER_AV_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_BEER * TAP_BEER_AV_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_BEER * TAP_BEER_AV_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_BEER * TAP_BEER_AV_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_BEER * TAP_BEER_AV_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_BEER * TAP_BEER_AV_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_BEER * TAP_BEER_AV_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_9"

# %%
results_9 =biogeme.estimate()

# %%
print(results_9)
# Out:
# Results for model [my model_9]
# Output file (HTML):			my model_9~00.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3751.836
# Likelihood ratio test:		2572.155
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7553.673
# Bayesian Information Criterion:	7691.988
# Final gradient norm:		0.1191385
# ASC_ARC        : -0.161[0.181 -0.886 0.376][0.177 -0.907 0.364]
# ASC_ATL        : -0.749[0.104 -7.22 5.32e-13][0.103 -7.28 3.44e-13]
# ASC_BC         : -0.171[0.111 -1.54 0.124][0.115 -1.49 0.137]
# ASC_BM         : -1.7[0.162 -10.5 0][0.157 -10.9 0]
# ASC_COP        : -2.92[0.454 -6.44 1.22e-10][0.452 -6.46 1.08e-10]
# ASC_COR        : -0.193[0.141 -1.37 0.171][0.138 -1.4 0.162]
# ASC_ELA        : -0.605[0.11 -5.47 4.44e-08][0.11 -5.52 3.4e-08]
# ASC_GIA        : -0.397[0.0978 -4.06 5e-05][0.0947 -4.19 2.77e-05]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1\

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2\

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3\

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4\

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5\

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6\

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7\

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8\

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9\

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10\

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11\

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12\

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13\

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14\

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15\

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16\

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17\

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18\

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19\

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20\

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21\

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_10"

# %%
results_10 = biogeme.estimate()

# %%
print(results_10)
# Out:
# Results for model [my model_10]
# Output file (HTML):			my model_10.html
# Nbr of parameters:		24
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3753.117
# Likelihood ratio test:		2569.594
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7554.233
# Bayesian Information Criterion:	7687.016
# Final gradient norm:		0.08241749
# ASC_ARC        : -1.85[0.178 -10.4 0][0.17 -10.9 0]
# ASC_ATL        : -0.784[0.104 -7.54 4.57e-14][0.102 -7.66 1.89e-14]
# ASC_BC         : -0.206[0.112 -1.85 0.0648][0.116 -1.79 0.074]
# ASC_BM         : -1.38[0.122 -11.4 0][0.121 -11.4 0]
# ASC_COP        : -2.94[0.445 -6.59 4.3e-11][0.444 -6.61 3.82e-11]
# ASC_COR        : -0.193[0.141 -1.37 0.171][0.138 -1.4 0.163]
# ASC_ELA        : -0.681[0.114 -5.96 2.53e-09][0.112 -6.08 1.19e-09]
# ASC_GIA        : -0.413[0.0973 -4.24 2.21e-05][0.094 -4.39 1.12e-05]
# ASC_HOD        : -1.06[0.245 -4.34 1.43e-05][0.245 -4.34 1.41e-05]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch_hot_meal_av_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch_hot_meal_av_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch_hot_meal_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch_hot_meal_av_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch_hot_meal_av_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch_hot_meal_av_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch_hot_meal_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch_hot_meal_av_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch_hot_meal_av_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch_hot_meal_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch_hot_meal_av_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch_hot_meal_av_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch_hot_meal_av_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch_hot_meal_av_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch_hot_meal_av_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch_hot_meal_av_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch_hot_meal_av_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch_hot_meal_av_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch_hot_meal_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch_hot_meal_av_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch_hot_meal_av_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_11"

# %%
results_11 = biogeme.estimate()

# %%
print(results_11)
# Out:
# Results for model [my model_11]
# Output file (HTML):			my model_11.html
# Nbr of parameters:		24
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3753.114
# Likelihood ratio test:		2569.601
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7554.227
# Bayesian Information Criterion:	7687.01
# Final gradient norm:		0.09648318
# ASC_ARC        : -1.83[0.181 -10.1 0][0.169 -10.8 0]
# ASC_ATL        : -0.752[0.107 -7.05 1.74e-12][0.107 -7.04 1.89e-12]
# ASC_BC         : -0.18[0.112 -1.61 0.108][0.115 -1.56 0.118]
# ASC_BM         : -1.75[0.159 -11 0][0.155 -11.3 0]
# ASC_COP        : -2.83[0.64 -4.42 9.82e-06][0.526 -5.38 7.47e-08]
# ASC_COR        : -0.19[0.141 -1.35 0.178][0.139 -1.37 0.17]
# ASC_ELA        : -0.619[0.11 -5.6 2.12e-08][0.109 -5.67 1.46e-08]
# ASC_GIA        : -0.411[0.0977 -4.21 2.59e-05][0.0946 -4.34 1.39e-05]
# ASC_HOD        : -1.03[0.392 -2.64 0.00835][0.295 -3.51 0.000446]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_12"

# %%
results_12 = biogeme.estimate()

# %%
print(results_12)
# Out:
# Results for model [my model_12]
# Output file (HTML):			my model_12.html
# Nbr of parameters:		24
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3753.028
# Likelihood ratio test:		2569.771
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7554.057
# Bayesian Information Criterion:	7686.84
# Final gradient norm:		0.06162021
# ASC_ARC        : -1.86[0.18 -10.4 0][0.169 -11 0]
# ASC_ATL        : -0.781[0.105 -7.41 1.29e-13][0.107 -7.31 2.71e-13]
# ASC_BC         : -0.172[0.111 -1.54 0.123][0.115 -1.49 0.135]
# ASC_BM         : -1.75[0.164 -10.7 0][0.156 -11.3 0]
# ASC_COP        : -3.32[0.562 -5.9 3.71e-09][0.523 -6.34 2.37e-10]
# ASC_COR        : -0.172[0.14 -1.22 0.221][0.138 -1.25 0.212]
# ASC_ELA        : -0.636[0.11 -5.75 8.68e-09][0.109 -5.84 5.35e-09]
# ASC_GIA        : -0.448[0.0942 -4.75 2.02e-06][0.0918 -4.87 1.09e-06]
# ASC_HOD        : -1.35[0.334 -4.06 4.98e-05][0.296 -4.58 4.69e-06]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="my model_13"
results_13 = biogeme.estimate()

# %%
print(results_13)
# Out:
# Results for model [my model_13]
# Output file (HTML):			my model_13.html
# Nbr of parameters:		24
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3752.94
# Likelihood ratio test:		2569.949
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7553.879
# Bayesian Information Criterion:	7686.662
# Final gradient norm:		0.1050682
# ASC_ARC        : -1.86[0.18 -10.4 0][0.17 -11 0]
# ASC_ATL        : -0.781[0.105 -7.41 1.25e-13][0.107 -7.32 2.56e-13]
# ASC_BC         : -0.171[0.111 -1.54 0.124][0.115 -1.49 0.136]
# ASC_BM         : -1.75[0.164 -10.7 0][0.156 -11.2 0]
# ASC_COP        : -3.76[0.793 -4.74 2.18e-06][0.693 -5.42 5.86e-08]
# ASC_COR        : -0.172[0.14 -1.23 0.22][0.138 -1.25 0.211]
# ASC_ELA        : -0.634[0.11 -5.75 8.9e-09][0.109 -5.83 5.41e-09]
# ASC_GIA        : -0.447[0.0941 -4.75 2.08e-06][0.0918 -4.87 1.12e-06]
# ASC_HOD        : -1.36[0.331 -4.12 3.81e-05][0.292 -4.67 2.99e-06]
# ...

# %% [markdown]
# 466 out of 1868 samples have no distance data.
# 12 out of the remaining 1402 samples miss the distance of the chosen alternative.

# %%
1868-466
# Out:
# 1402

# %%
for i in range(1868):
# Out:
# RangeIndex(start=0, stop=1868, step=1)

# %%
x = pd.DataFrame([[1, 2, 3], [4, 5, 6]])
x
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
import numpy as np
x.iloc[:,np.array(x.iloc[1]>4)]
# Out:
#    1  2
# 0  2  3
# 1  5  6

# %%
np.array(n)>3
# Out:
# array([False,  True])

# %%
m=zip([0, 1], [1, 2])
n = [x.iloc[i] for i in list(m)]
x.iloc[np.array(n)>3, :]
# Out:
#    0  1  2
# 1  4  5  6

# %%
l1 = pandas.iloc[:,11];

# %%
l2 = [415]*1868 + l1.values

# %%
m = zip(range(1868),l2)
n = [pandas.iloc[i] for i in list(m)]

# %%
data_no_choice_miss = pandas.iloc[np.array(n)>-1, :]

# %%
m = [sum(pandas.iloc[i,416:437]) for i in range(1868)]

# %%
data_all_missing = pandas.iloc[np.array(m)<=-21,:]

# %%
database_all_missing = db.Database("Dataset_missing",data_all_missing)

# %%
database_no_missing = db.Database("Dataset_no_missing", data_no_choice_miss)

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_EVA * eva_1 * lunch_hot_meal_av_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_EVA * eva_2 * lunch_hot_meal_av_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_EVA * eva_3 * lunch_hot_meal_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_EVA * eva_4 * lunch_hot_meal_av_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_EVA * eva_5 * lunch_hot_meal_av_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_EVA * eva_6 * lunch_hot_meal_av_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_EVA * eva_7 * lunch_hot_meal_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_EVA * eva_8 * lunch_hot_meal_av_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_EVA * eva_9 * lunch_hot_meal_av_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_EVA * eva_10 * lunch_hot_meal_av_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_EVA * eva_11 * lunch_hot_meal_av_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_EVA * eva_12 * lunch_hot_meal_av_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_EVA * eva_13 * lunch_hot_meal_av_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
     + BETA_EVA * eva_14 * lunch_hot_meal_av_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
     + BETA_EVA * eva_15 * lunch_hot_meal_av_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_EVA * eva_16 * lunch_hot_meal_av_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_EVA * eva_17 * lunch_hot_meal_av_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_EVA * eva_18 * lunch_hot_meal_av_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_EVA * eva_19 * lunch_hot_meal_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_EVA * eva_20 * lunch_hot_meal_av_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_EVA * eva_21 * lunch_hot_meal_av_21 \

V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database_no_missing,logprob)
biogeme.modelName="compare_model_1"
results_c_1 = biogeme.estimate()

# %%
print(results_c_1)
# Out:
# Results for model [compare_model_1]
# Output file (HTML):			compare_model_1.html
# Nbr of parameters:		23
# Sample size:			1390
# Excluded data:			0
# Init log likelihood:		-3757.829
# Final log likelihood:		-2916.98
# Likelihood ratio test:		1681.697
# Rho square:			0.224
# Rho bar square:			0.218
# Akaike Information Criterion:	5879.961
# Bayesian Information Criterion:	6000.413
# Final gradient norm:		0.05612549
# ASC_ARC        : -1.78[0.251 -7.1 1.24e-12][0.236 -7.57 3.71e-14]
# ASC_ATL        : -0.875[0.181 -4.85 1.26e-06][0.175 -5.01 5.53e-07]
# ASC_BC         : -0.359[0.139 -2.57 0.0102][0.142 -2.53 0.0115]
# ASC_BM         : -2.21[0.321 -6.88 5.79e-12][0.306 -7.22 5.15e-13]
# ASC_COP        : -2.63[0.999 -2.63 0.00859][0.908 -2.89 0.00383]
# ASC_COR        : -0.365[0.15 -2.44 0.0147][0.152 -2.4 0.0165]
# ASC_ELA        : -0.799[0.297 -2.69 0.0071][0.279 -2.87 0.00411]
# ASC_GIA        : -0.502[0.29 -1.73 0.083][0.277 -1.81 0.0696]
# ...

# %%
V1 = ASC_KLE \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_EVA * eva_1 * lunch_hot_meal_av_1 \

V2 = ASC_BC \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_EVA * eva_2 * lunch_hot_meal_av_2 \

V3 = ASC_BM \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_EVA * eva_3 * lunch_hot_meal_av_3 \

V4 = ASC_ELA \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_EVA * eva_4 * lunch_hot_meal_av_4 \

V5 = ASC_INM \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_EVA * eva_5 * lunch_hot_meal_av_5 \

V6 = ASC_MX \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_EVA * eva_6 * lunch_hot_meal_av_6 \

V7 = ASC_PH \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_EVA * eva_7 * lunch_hot_meal_av_7 \

V8 = ASC_ARC \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_EVA * eva_8 * lunch_hot_meal_av_8 \

V9 = ASC_ATL \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_EVA * eva_9 * lunch_hot_meal_av_9 \

V10 = ASC_COP \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_EVA * eva_10 * lunch_hot_meal_av_10 \

V11 = ASC_COR \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_EVA * eva_11 * lunch_hot_meal_av_11 \

V12 = ASC_GIA \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_EVA * eva_12 * lunch_hot_meal_av_12 \

V13 = ASC_PAR \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_EVA * eva_13 * lunch_hot_meal_av_13 \

V14 = ASC_VIN \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
     + BETA_EVA * eva_14 * lunch_hot_meal_av_14 \

V15 = ASC_ESP \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
     + BETA_EVA * eva_15 * lunch_hot_meal_av_15 \

V16 = ASC_ORN \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_EVA * eva_16 * lunch_hot_meal_av_16 \

V17 = ASC_PIZ \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_EVA * eva_17 * lunch_hot_meal_av_17 \

V18 = ASC_KEB \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_EVA * eva_18 * lunch_hot_meal_av_18 \

V19 = ASC_SAT \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_EVA * eva_19 * lunch_hot_meal_av_19 \

V20 = ASC_HOD \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_EVA * eva_20 * lunch_hot_meal_av_20 \

V21 = ASC_VAL \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_EVA * eva_21 * lunch_hot_meal_av_21 

V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database_all_missing,logprob)
biogeme.modelName="compare_model_2"
results_c_2 = biogeme.estimate()

# %%
print(results_c_2)
# Out:
# Results for model [compare_model_2]
# Output file (HTML):			compare_model_2.html
# Nbr of parameters:		22
# Sample size:			466
# Excluded data:			0
# Init log likelihood:		-1247.062
# Final log likelihood:		-1107.103
# Likelihood ratio test:		279.9195
# Rho square:			0.112
# Rho bar square:			0.0946
# Akaike Information Criterion:	2258.205
# Bayesian Information Criterion:	2349.377
# Final gradient norm:		0.02152439
# ASC_ARC        : -2.64[0.516 -5.11 3.15e-07][0.54 -4.89 1.02e-06]
# ASC_ATL        : -0.875[0.344 -2.55 0.0108][0.329 -2.66 0.00786]
# ASC_BC         : -0.372[0.21 -1.77 0.076][0.233 -1.6 0.109]
# ASC_BM         : -1.28[0.627 -2.05 0.0408][0.661 -1.94 0.0521]
# ASC_COP        : -3.52[1.93 -1.82 0.0685][1.88 -1.87 0.0616]
# ASC_COR        : -0.468[0.335 -1.4 0.163][0.34 -1.38 0.168]
# ASC_ELA        : 0.291[0.564 0.516 0.606][0.592 0.491 0.623]
# ASC_GIA        : 0.514[0.557 0.924 0.356][0.576 0.893 0.372]
# ASC_HOD        : -1.88[1.27 -1.49 0.137][1.19 -1.58 0.115]
# ...

# %% [markdown]
# Capacity?

# %%
BETA_CAPACITY = Beta('BETA_CAPACITY', 0, -100, 100, 0)

# %%
capacity_scaled_1 = (capacity_at_lunch_inside_av_1 + capacity_at_lunch_outside_av_1) / 10
capacity_scaled_2 = (capacity_at_lunch_inside_av_2 + capacity_at_lunch_outside_av_2) / 10
capacity_scaled_3 = (capacity_at_lunch_inside_av_3 + capacity_at_lunch_outside_av_3) / 10
capacity_scaled_4 = (capacity_at_lunch_inside_av_4 + capacity_at_lunch_outside_av_4) / 10
capacity_scaled_5 = (capacity_at_lunch_inside_av_5 + capacity_at_lunch_outside_av_5) / 10
capacity_scaled_6 = (capacity_at_lunch_inside_av_6 + capacity_at_lunch_outside_av_6) / 10
capacity_scaled_7 = (capacity_at_lunch_inside_av_7 + capacity_at_lunch_outside_av_7) / 10
capacity_scaled_8 = (capacity_at_lunch_inside_av_8 + capacity_at_lunch_outside_av_8) / 10
capacity_scaled_9 = (capacity_at_lunch_inside_av_9 + capacity_at_lunch_outside_av_9)/ 10
capacity_scaled_10 = (capacity_at_lunch_inside_av_10 + capacity_at_lunch_outside_av_10) / 10
capacity_scaled_11 = (capacity_at_lunch_inside_av_11 + capacity_at_lunch_outside_av_11) / 10
capacity_scaled_12 = (capacity_at_lunch_inside_av_12 + capacity_at_lunch_outside_av_12) / 10
capacity_scaled_13 = (capacity_at_lunch_inside_av_13 + capacity_at_lunch_outside_av_13) / 10
capacity_scaled_14 = (capacity_at_lunch_inside_av_14 + capacity_at_lunch_outside_av_14) / 10
capacity_scaled_15 = (capacity_at_lunch_inside_av_15 + capacity_at_lunch_outside_av_15) / 10
capacity_scaled_16 = (capacity_at_lunch_inside_av_16 + capacity_at_lunch_outside_av_16) / 10
capacity_scaled_17 = (capacity_at_lunch_inside_av_17 + capacity_at_lunch_outside_av_17) / 10
capacity_scaled_18 = (capacity_at_lunch_inside_av_18 + capacity_at_lunch_outside_av_18) / 10
capacity_scaled_19 = (capacity_at_lunch_inside_av_19 + capacity_at_lunch_outside_av_19) / 10
capacity_scaled_20 =  (capacity_at_lunch_inside_av_20 + capacity_at_lunch_outside_av_20) / 10
capacity_scaled_21 = (capacity_at_lunch_inside_av_21 + capacity_at_lunch_outside_av_21) / 10

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \
    + BETA_CAPACITY * capacity_scaled_1

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \
    + BETA_CAPACITY *  capacity_scaled_2

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \
    + BETA_CAPACITY * capacity_scaled_3

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \
    + BETA_CAPACITY * capacity_scaled_4

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \
    + BETA_CAPACITY * capacity_scaled_5

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \
    + BETA_CAPACITY * capacity_scaled_6

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \
    + BETA_CAPACITY * capacity_scaled_7

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \
    + BETA_CAPACITY * capacity_scaled_8

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \
    + BETA_CAPACITY * capacity_scaled_9

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \
    + BETA_CAPACITY * capacity_scaled_10

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \
    + BETA_CAPACITY * capacity_scaled_11

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \
    + BETA_CAPACITY * capacity_scaled_12

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \
    + BETA_CAPACITY * capacity_scaled_13

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \
    + BETA_CAPACITY * capacity_scaled_14

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \
    + BETA_CAPACITY * capacity_scaled_15

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \
    + BETA_CAPACITY * capacity_scaled_16

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \
    + BETA_CAPACITY * capacity_scaled_17

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \
    + BETA_CAPACITY * capacity_scaled_18

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \
    + BETA_CAPACITY * capacity_scaled_19

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \
    + BETA_CAPACITY * capacity_scaled_20

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \
    + BETA_CAPACITY * capacity_scaled_21

V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_1"
results_i_1 = biogeme.estimate()

# %%
print(results_i_1)
# Out:
# Results for model [improve_model_1]
# Output file (HTML):			improve_model_1.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3750.346
# Likelihood ratio test:		2575.135
# Rho square:			0.256
# Rho bar square:			0.251
# Akaike Information Criterion:	7550.693
# Bayesian Information Criterion:	7689.008
# Final gradient norm:		0.03484512
# ASC_ARC        : -1.78[0.183 -9.7 0][0.171 -10.4 0]
# ASC_ATL        : -0.711[0.109 -6.5 7.99e-11][0.111 -6.4 1.56e-10]
# ASC_BC         : -0.113[0.115 -0.984 0.325][0.117 -0.963 0.336]
# ASC_BM         : -1.71[0.165 -10.4 0][0.156 -10.9 0]
# ASC_COP        : -3.04[0.568 -5.35 8.7e-08][0.52 -5.84 5.08e-09]
# ASC_COR        : -0.222[0.141 -1.58 0.115][0.138 -1.61 0.107]
# ASC_ELA        : -0.582[0.113 -5.15 2.57e-07][0.112 -5.21 1.88e-07]
# ASC_GIA        : -0.385[0.0982 -3.92 8.69e-05][0.096 -4.01 5.96e-05]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_1 + CAPACITY_OUTSIDE_1 * SUN_AND_HEAT_MIN_20)  

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2  \
    + BETA_CAPACITY * (CAPACITY_INSIDE_2 + CAPACITY_OUTSIDE_2 * SUN_AND_HEAT_MIN_20)

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3  \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_3 + CAPACITY_OUTSIDE_3 * SUN_AND_HEAT_MIN_20)

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_4 + CAPACITY_OUTSIDE_4 * SUN_AND_HEAT_MIN_20)

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_5 + CAPACITY_OUTSIDE_5 * SUN_AND_HEAT_MIN_20)

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_6 + CAPACITY_OUTSIDE_6 * SUN_AND_HEAT_MIN_20)

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_7 + CAPACITY_OUTSIDE_7 * SUN_AND_HEAT_MIN_20)

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_8 + CAPACITY_OUTSIDE_8 * SUN_AND_HEAT_MIN_20)

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_9 + CAPACITY_OUTSIDE_9 * SUN_AND_HEAT_MIN_20)

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_10 + CAPACITY_OUTSIDE_10 * SUN_AND_HEAT_MIN_20)

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_11 + CAPACITY_OUTSIDE_11 * SUN_AND_HEAT_MIN_20)

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_12 + CAPACITY_OUTSIDE_12 * SUN_AND_HEAT_MIN_20)

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_13 + CAPACITY_OUTSIDE_13 * SUN_AND_HEAT_MIN_20)

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_14 + CAPACITY_OUTSIDE_14 * SUN_AND_HEAT_MIN_20)

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_15 + CAPACITY_OUTSIDE_15 * SUN_AND_HEAT_MIN_20)

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_16 + CAPACITY_OUTSIDE_16 * SUN_AND_HEAT_MIN_20)

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_17 + CAPACITY_OUTSIDE_17 * SUN_AND_HEAT_MIN_20)

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 \
    + BETA_CAPACITY * (CAPACITY_INSIDE_18 + CAPACITY_OUTSIDE_18 * SUN_AND_HEAT_MIN_20)

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_19 + CAPACITY_OUTSIDE_19 * SUN_AND_HEAT_MIN_20)

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20  \
    + BETA_CAPACITY * (CAPACITY_INSIDE_20 + CAPACITY_OUTSIDE_20 * SUN_AND_HEAT_MIN_20)

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21  \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 \
    + BETA_CAPACITY *  (CAPACITY_INSIDE_21 + CAPACITY_OUTSIDE_21 * SUN_AND_HEAT_MIN_20)

V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_2"
results_i_2 = biogeme.estimate()

# %%
print(results_i_2)
# Out:
# Results for model [improve_model_2]
# Output file (HTML):			improve_model_2.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3755.708
# Likelihood ratio test:		2564.413
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7561.415
# Bayesian Information Criterion:	7699.731
# Final gradient norm:		0.0967233
# ASC_ARC        : -1.74[0.299 -5.8 6.5e-09][0.295 -5.9 3.72e-09]
# ASC_ATL        : -0.692[0.223 -3.11 0.00187][0.22 -3.15 0.00163]
# ASC_BC         : -0.0849[0.193 -0.44 0.66][0.203 -0.419 0.675]
# ASC_BM         : -1.25[0.215 -5.82 5.8e-09][0.204 -6.15 7.67e-10]
# ASC_COP        : -2.62[1.06 -2.47 0.0135][1.06 -2.47 0.0134]
# ASC_COR        : -0.106[0.143 -0.739 0.46][0.141 -0.748 0.454]
# ASC_ELA        : -0.578[0.401 -1.44 0.15][0.42 -1.38 0.169]
# ASC_GIA        : -0.315[0.258 -1.22 0.223][0.267 -1.18 0.238]
# ...

# %%
BETA_SANDWICH = Beta('BETA_SANDWICH', 0, -100, 100, 0)

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch_hot_meal_av_1 \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch_hot_meal_av_1 \
    + BETA_SANDWICH * SANDWICH_AV_1 \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch_hot_meal_av_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch_hot_meal_av_2 \
    + BETA_SANDWICH * SANDWICH_AV_2 \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch_hot_meal_av_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch_hot_meal_av_3 \
    + BETA_SANDWICH * SANDWICH_AV_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch_hot_meal_av_4 \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch_hot_meal_av_4 \
    + BETA_SANDWICH * SANDWICH_AV_4 \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch_hot_meal_av_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch_hot_meal_av_5 \
    + BETA_SANDWICH * SANDWICH_AV_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch_hot_meal_av_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch_hot_meal_av_6 \
    + BETA_SANDWICH * SANDWICH_AV_6 \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch_hot_meal_av_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch_hot_meal_av_7 \
    + BETA_SANDWICH * SANDWICH_AV_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch_hot_meal_av_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch_hot_meal_av_8 \
    + BETA_SANDWICH * SANDWICH_AV_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch_hot_meal_av_9 \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch_hot_meal_av_9 \
    + BETA_SANDWICH * SANDWICH_AV_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch_hot_meal_av_10 \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch_hot_meal_av_10 \
    + BETA_SANDWICH * SANDWICH_AV_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch_hot_meal_av_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch_hot_meal_av_11 \
    + BETA_SANDWICH * SANDWICH_AV_11 \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch_hot_meal_av_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch_hot_meal_av_12 \
    + BETA_SANDWICH * SANDWICH_AV_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch_hot_meal_av_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch_hot_meal_av_13 \
    + BETA_SANDWICH * SANDWICH_AV_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch_hot_meal_av_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch_hot_meal_av_14 \
    + BETA_SANDWICH * SANDWICH_AV_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch_hot_meal_av_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch_hot_meal_av_15 \
    + BETA_SANDWICH * SANDWICH_AV_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch_hot_meal_av_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch_hot_meal_av_16 \
    + BETA_SANDWICH * SANDWICH_AV_16 \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch_hot_meal_av_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch_hot_meal_av_17 \
    + BETA_SANDWICH * SANDWICH_AV_17 \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch_hot_meal_av_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch_hot_meal_av_18 \
    + BETA_SANDWICH * SANDWICH_AV_18 \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch_hot_meal_av_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch_hot_meal_av_19 \
    + BETA_SANDWICH * SANDWICH_AV_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch_hot_meal_av_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch_hot_meal_av_20 \
    + BETA_SANDWICH * SANDWICH_AV_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch_hot_meal_av_21 \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch_hot_meal_av_21 \
    + BETA_SANDWICH * SANDWICH_AV_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_3"
results_i_3 = biogeme.estimate()

# %%
print(results_i_3)
# Out:
# Results for model [improve_model_3]
# Output file (HTML):			improve_model_3.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3753.113
# Likelihood ratio test:		2569.602
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7556.226
# Bayesian Information Criterion:	7694.542
# Final gradient norm:		0.08347419
# ASC_ARC        : -1.83[0.181 -10.1 0][0.169 -10.8 0]
# ASC_ATL        : -0.753[0.107 -7.06 1.63e-12][0.107 -7.05 1.8e-12]
# ASC_BC         : 1.09[0.194 5.6 2.15e-08][0.158 6.88 5.94e-12]
# ASC_BM         : -0.484[0.218 -2.22 0.0265][0.186 -2.61 0.00912]
# ASC_COP        : -1.58[0.517 -3.05 0.00228][0.45 -3.51 0.000455]
# ASC_COR        : 1.08[0.202 5.34 9.07e-08][0.169 6.37 1.95e-10]
# ASC_ELA        : -0.619[0.11 -5.61 2.06e-08][0.109 -5.67 1.42e-08]
# ASC_GIA        : -0.411[0.0977 -4.21 2.55e-05][0.0946 -4.35 1.37e-05]
# ...

# %%
BETA_EMPLOYEE = Beta('BETA_EMPLOYEE', 0, -100, 100, 0)
BETA_STUDENT = Beta('BETA_STUDENT', 0, -100, 100, 0)


V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_STUDENT * lunch_price_min_student_1 \
    + BETA_EMPLOYEE * lunch_price_min_employee_1\
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_STUDENT * lunch_price_min_student_2 \
    + BETA_EMPLOYEE * lunch_price_min_employee_2\
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_STUDENT * lunch_price_min_student_3 \
    + BETA_EMPLOYEE * lunch_price_min_employee_3\
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_STUDENT * lunch_price_min_student_4 \
    + BETA_EMPLOYEE * lunch_price_min_employee_4\
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_STUDENT * lunch_price_min_student_5 \
    + BETA_EMPLOYEE * lunch_price_min_employee_5\
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_STUDENT * lunch_price_min_student_6 \
    + BETA_EMPLOYEE * lunch_price_min_employee_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_STUDENT * lunch_price_min_student_7 \
    + BETA_EMPLOYEE * lunch_price_min_employee_7\
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_STUDENT * lunch_price_min_student_8 \
    + BETA_EMPLOYEE * lunch_price_min_employee_8\
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_STUDENT * lunch_price_min_student_9 \
    + BETA_EMPLOYEE * lunch_price_min_employee_9\
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_STUDENT * lunch_price_min_student_10 \
    + BETA_EMPLOYEE * lunch_price_min_employee_10\
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_STUDENT * lunch_price_min_student_11 \
    + BETA_EMPLOYEE * lunch_price_min_employee_11 \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_STUDENT * lunch_price_min_student_12 \
    + BETA_EMPLOYEE * lunch_price_min_employee_12 \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_STUDENT * lunch_price_min_student_13 \
    + BETA_EMPLOYEE * lunch_price_min_employee_13 \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_STUDENT * lunch_price_min_student_14 \
    + BETA_EMPLOYEE * lunch_price_min_employee_14 \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_STUDENT * lunch_price_min_student_15 \
    + BETA_EMPLOYEE * lunch_price_min_employee_15 \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_STUDENT * lunch_price_min_student_16 \
    + BETA_EMPLOYEE * lunch_price_min_employee_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_STUDENT * lunch_price_min_student_17  \
    + BETA_EMPLOYEE * lunch_price_min_employee_17 \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_STUDENT * lunch_price_min_student_18  \
    + BETA_EMPLOYEE * lunch_price_min_employee_18 \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_STUDENT * lunch_price_min_student_19  \
    + BETA_EMPLOYEE * lunch_price_min_employee_19 \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_STUDENT * lunch_price_min_student_20 \
    + BETA_EMPLOYEE * lunch_price_min_employee_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_STUDENT * lunch_price_min_student_21 \
    + BETA_EMPLOYEE * lunch_price_min_employee_21\
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_4"
results_i_4 = biogeme.estimate()

# %%
print(results_i_4)
# Out:
# Results for model [improve_model_4]
# Output file (HTML):			improve_model_4~00.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3748.997
# Likelihood ratio test:		2577.834
# Rho square:			0.256
# Rho bar square:			0.251
# Akaike Information Criterion:	7547.993
# Bayesian Information Criterion:	7686.309
# Final gradient norm:		0.08711044
# ASC_ARC        : -1.86[0.18 -10.3 0][0.169 -11 0]
# ASC_ATL        : -0.779[0.105 -7.39 1.45e-13][0.107 -7.29 3.02e-13]
# ASC_BC         : -0.171[0.112 -1.54 0.125][0.115 -1.49 0.137]
# ASC_BM         : -1.75[0.164 -10.7 0][0.156 -11.2 0]
# ASC_COP        : -3.34[0.563 -5.93 2.94e-09][0.52 -6.43 1.3e-10]
# ASC_COR        : -0.175[0.14 -1.25 0.212][0.138 -1.27 0.203]
# ASC_ELA        : -0.633[0.11 -5.73 1e-08][0.109 -5.81 6.17e-09]
# ASC_GIA        : -0.442[0.0942 -4.69 2.71e-06][0.0918 -4.81 1.48e-06]
# ...

# %%
V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \
    + BETA_CAPACITY * capacity_scaled_1 * (1 - SANDWICH_AV_1)\

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \
    + BETA_CAPACITY *  capacity_scaled_2 * (1 - SANDWICH_AV_2)\

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \
    + BETA_CAPACITY * capacity_scaled_3 * (1 - SANDWICH_AV_3)\

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \
    + BETA_CAPACITY * capacity_scaled_4 * (1 - SANDWICH_AV_4)\

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \
    + BETA_CAPACITY * capacity_scaled_5 * (1 - SANDWICH_AV_5)\

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \
    + BETA_CAPACITY * capacity_scaled_6 * (1 - SANDWICH_AV_6)\

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \
    + BETA_CAPACITY * capacity_scaled_7 * (1 - SANDWICH_AV_7)\

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \
    + BETA_CAPACITY * capacity_scaled_8 * (1 - SANDWICH_AV_8)\

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \
    + BETA_CAPACITY * capacity_scaled_9 * (1 - SANDWICH_AV_9)\

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \
    + BETA_CAPACITY * capacity_scaled_10 * (1 - SANDWICH_AV_10)\

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \
    + BETA_CAPACITY * capacity_scaled_11 * (1 - SANDWICH_AV_11)\

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \
    + BETA_CAPACITY * capacity_scaled_12 * (1 - SANDWICH_AV_12)\

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \
    + BETA_CAPACITY * capacity_scaled_13 * (1 - SANDWICH_AV_13)\

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \
    + BETA_CAPACITY * capacity_scaled_14 * (1 - SANDWICH_AV_14)\

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \
    + BETA_CAPACITY * capacity_scaled_15 * (1 - SANDWICH_AV_15)\

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \
    + BETA_CAPACITY * capacity_scaled_16 * (1 - SANDWICH_AV_16)\

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \
    + BETA_CAPACITY * capacity_scaled_17 * (1 - SANDWICH_AV_17)\

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \
    + BETA_CAPACITY * capacity_scaled_18 * (1 - SANDWICH_AV_18)\

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \
    + BETA_CAPACITY * capacity_scaled_19 * (1 - SANDWICH_AV_19)\

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \
    + BETA_CAPACITY * capacity_scaled_20 * (1 - SANDWICH_AV_20)\

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \
    + BETA_CAPACITY * capacity_scaled_21 * (1 - SANDWICH_AV_21)\

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_5"
results_i_5 = biogeme.estimate()

# %%
print(results_i_5)
# Out:
# Results for model [improve_model_5]
# Output file (HTML):			improve_model_5.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3750.442
# Likelihood ratio test:		2574.944
# Rho square:			0.256
# Rho bar square:			0.251
# Akaike Information Criterion:	7550.884
# Bayesian Information Criterion:	7689.199
# Final gradient norm:		0.08025164
# ASC_ARC        : -1.84[0.18 -10.2 0][0.169 -10.9 0]
# ASC_ATL        : -0.762[0.106 -7.21 5.47e-13][0.107 -7.11 1.13e-12]
# ASC_BC         : -0.219[0.114 -1.93 0.054][0.116 -1.88 0.0598]
# ASC_BM         : -1.77[0.164 -10.8 0][0.156 -11.3 0]
# ASC_COP        : -3.33[0.563 -5.92 3.25e-09][0.524 -6.36 2.06e-10]
# ASC_COR        : -0.451[0.187 -2.41 0.0161][0.185 -2.44 0.0145]
# ASC_ELA        : -0.635[0.11 -5.75 8.87e-09][0.109 -5.84 5.37e-09]
# ASC_GIA        : -0.443[0.0942 -4.71 2.53e-06][0.0918 -4.83 1.4e-06]
# ...

# %%
BETA_CAFE = Beta('BETA_CAFE', 0, -100, 100, 0)
BETA_REST = Beta('BETA_REST', 0, -100, 100, 0)
BETA_SELF = Beta('BETA_FAST', 0, -100, 100, 0)
BETA_CARA = Beta('BETA_CARA', 0, -100, 100, 0)



V1 = ASC_KLE \
    + BETA_CAFE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_CAFE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \

V3 = ASC_BM \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \

V4 = ASC_ELA \
   + BETA_CAFE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \

V5 = ASC_INM \
   + BETA_CAFE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_CAFE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \

V8 = ASC_ARC \
    + BETA_SELF * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_SELF * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_REST * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \

V11 = ASC_COR \
    + BETA_SELF * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \

V12 = ASC_GIA \
   + BETA_SELF * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_SELF * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_SELF * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_SELF * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_SELF * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_CARA * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_CARA * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_SELF * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \

V20 = ASC_HOD \
    + BETA_SELF * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_REST * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_6"
results_i_6 = biogeme.estimate()

# %%
print(results_i_6)
# Out:
# Results for model [improve_model_6]
# Output file (HTML):			improve_model_6~00.html
# Nbr of parameters:		27
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3815.589
# Likelihood ratio test:		2444.65
# Rho square:			0.243
# Rho bar square:			0.237
# Akaike Information Criterion:	7685.178
# Bayesian Information Criterion:	7834.558
# Final gradient norm:		0.07434584
# ASC_ARC        : -1.95[0.18 -10.9 0][0.17 -11.5 0]
# ASC_ATL        : -0.814[0.105 -7.74 9.99e-15][0.107 -7.62 2.51e-14]
# ASC_BC         : -0.427[0.122 -3.49 0.000485][0.122 -3.52 0.000439]
# ASC_BM         : -3.13[0.171 -18.4 0][0.175 -17.9 0]
# ASC_COP        : -4.05[0.663 -6.11 1e-09][0.753 -5.38 7.53e-08]
# ASC_COR        : -0.174[0.14 -1.25 0.212][0.137 -1.27 0.203]
# ASC_ELA        : -0.869[0.122 -7.1 1.22e-12][0.128 -6.78 1.17e-11]
# ASC_GIA        : -0.45[0.094 -4.79 1.7e-06][0.0915 -4.92 8.86e-07]
# ...

# %%
BETA_CAFE = Beta('BETA_CAFE', 0, -100, 100, 0)
BETA_REST = Beta('BETA_REST', 0, -100, 100, 0)
BETA_SELF = Beta('BETA_FAST', 0, -100, 100, 0)
BETA_CARA = Beta('BETA_CARA', 0, -100, 100, 0)


V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_CAFE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_CAFE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_CAFE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_CAFE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_CAFE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_SELF * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_SELF * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_REST * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_SELF * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_SELF * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_SELF * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_SELF * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_SELF * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_SELF * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_CARA * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_CARA * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_SELF * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch_hot_meal_av_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_SELF * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_REST * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_7"
results_i_7 = biogeme.estimate()

# %%
print(results_i_7)
# Out:
# Results for model [improve_model_7]
# Output file (HTML):			improve_model_7.html
# Nbr of parameters:		27
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3746.656
# Likelihood ratio test:		2582.517
# Rho square:			0.256
# Rho bar square:			0.251
# Akaike Information Criterion:	7547.311
# Bayesian Information Criterion:	7696.692
# Final gradient norm:		0.0880493
# ASC_ARC        : -1.79[0.18 -9.98 0][0.17 -10.6 0]
# ASC_ATL        : -0.723[0.105 -6.86 6.81e-12][0.105 -6.88 6.08e-12]
# ASC_BC         : -0.195[0.123 -1.58 0.114][0.119 -1.63 0.103]
# ASC_BM         : -1.7[0.161 -10.6 0][0.153 -11.1 0]
# ASC_COP        : -10.9[98.5 -0.11 0.912][0.216 -50.2 0]
# ASC_COR        : -0.146[0.142 -1.03 0.304][0.141 -1.04 0.297]
# ASC_ELA        : -0.782[0.116 -6.76 1.4e-11][0.117 -6.66 2.66e-11]
# ASC_GIA        : -0.51[0.0947 -5.39 7.13e-08][0.0933 -5.47 4.52e-08]
# ASC_HOD        : -0.543[0.322 -1.68 0.0925][0.289 -1.88 0.0607]
# ...

# %%
BETA_CAFE = Beta('BETA_CAFE', 0, -100, 100, 0)
BETA_REST = Beta('BETA_REST', 0, -100, 100, 0)
BETA_SELF = Beta('BETA_FAST', 0, -100, 100, 0)
BETA_CARA = Beta('BETA_CARA', 0, -100, 100, 0)

V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_CAFE * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_CAFE * eva_2 * lunch \

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_CAFE * eva_4 * lunch \

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_CAFE * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_CAFE * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_SELF * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_SELF * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_REST * eva_10 * lunch \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_SELF * eva_11 * lunch \

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_SELF * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_SELF * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_SELF * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_SELF * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_SELF * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_CARA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_CARA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_SELF * eva_19 * lunch \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_SELF * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_REST * eva_21 * lunch \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_8"
results_i_8 = biogeme.estimate()

# %%
print(results_i_8)
# Out:
# Results for model [improve_model_8]
# Output file (HTML):			improve_model_8~00.html
# Nbr of parameters:		27
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3751.053
# Likelihood ratio test:		2573.721
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7556.107
# Bayesian Information Criterion:	7705.488
# Final gradient norm:		0.07654464
# ASC_ARC        : -1.88[0.18 -10.4 0][0.17 -11.1 0]
# ASC_ATL        : -0.792[0.106 -7.48 7.22e-14][0.108 -7.36 1.8e-13]
# ASC_BC         : -0.257[0.121 -2.12 0.0336][0.12 -2.15 0.0313]
# ASC_BM         : -1.78[0.165 -10.8 0][0.157 -11.3 0]
# ASC_COP        : -8.93[33.7 -0.265 0.791][0.237 -37.7 0]
# ASC_COR        : -0.14[0.142 -0.98 0.327][0.14 -0.995 0.32]
# ASC_ELA        : -0.702[0.117 -6.02 1.77e-09][0.115 -6.08 1.23e-09]
# ASC_GIA        : -0.439[0.0943 -4.66 3.19e-06][0.0919 -4.78 1.72e-06]
# ASC_HOD        : -1.48[0.354 -4.17 3e-05][0.315 -4.69 2.71e-06]
# ...

# %%
BETA_BREAK_AFTER = Beta('BETA_BREAK_AFTER', 0, -100, 100, 0)
BETA_DINNER = Beta('BETA_DINNER', 0, -100, 100, 0)


V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 * lunch \
    + BETA_BREAK_AFTER * distance_1 * (morning + lunch) \
    + BETA_DINNER * distance_1 * dinner \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 * lunch \
    + BETA_BREAK_AFTER * distance_2 * (morning + lunch) \
    + BETA_DINNER * distance_3 * dinner \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \

V3 = ASC_BM \
    + BETA_DISTANCE * distance_3 * lunch \
    + BETA_BREAK_AFTER * distance_3 * (morning + lunch) \
    + BETA_DINNER * distance_3 * dinner \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \

V4 = ASC_ELA \
    + BETA_DISTANCE * distance_4 * lunch \
    + BETA_BREAK_AFTER * distance_4 * (morning + lunch) \
    + BETA_DINNER * distance_4 * dinner \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \

V5 = ASC_INM \
    + BETA_DISTANCE * distance_5 * lunch \
    + BETA_BREAK_AFTER * distance_5 * (morning + lunch) \
    + BETA_DINNER * distance_5 * dinner \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 * lunch \
    + BETA_BREAK_AFTER * distance_6 * (morning + lunch) \
    + BETA_DINNER * distance_6 * dinner \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 * lunch \
    + BETA_BREAK_AFTER * distance_7 * (morning + lunch) \
    + BETA_DINNER * distance_7 * dinner \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 * lunch \
    + BETA_BREAK_AFTER * distance_8 * (morning + lunch) \
    + BETA_DINNER * distance_8 * dinner \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 * lunch \
    + BETA_BREAK_AFTER * distance_9 * (morning + lunch) \
    + BETA_DINNER * distance_9 * dinner \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 * lunch \
    + BETA_BREAK_AFTER * distance_10 * (morning + lunch) \
    + BETA_DINNER * distance_10 * dinner \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 * lunch \
    + BETA_BREAK_AFTER * distance_11 * (morning + lunch) \
    + BETA_DINNER * distance_11 * dinner \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \

V12 = ASC_GIA \
    + BETA_DISTANCE * distance_12 * lunch \
    + BETA_BREAK_AFTER * distance_12 * (morning + lunch) \
    + BETA_DINNER * distance_12 * dinner \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 * lunch \
    + BETA_BREAK_AFTER * distance_13 * (morning + lunch) \
    + BETA_DINNER * distance_13 * dinner \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 * lunch \
    + BETA_BREAK_AFTER * distance_14 * (morning + lunch) \
    + BETA_DINNER * distance_14 * dinner \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 * lunch \
    + BETA_BREAK_AFTER * distance_15 * (morning + lunch) \
    + BETA_DINNER * distance_15 * dinner \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 * lunch \
    + BETA_BREAK_AFTER * distance_16 * (morning + lunch) \
    + BETA_DINNER * distance_16 * dinner \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 * lunch \
    + BETA_BREAK_AFTER * distance_17 * (morning + lunch) \
    + BETA_DINNER * distance_17 * dinner \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 * lunch \
    + BETA_BREAK_AFTER * distance_18 * (morning + lunch) \
    + BETA_DINNER * distance_18 * dinner \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 * lunch \
    + BETA_BREAK_AFTER * distance_19 * (morning + lunch) \
    + BETA_DINNER * distance_19 * dinner \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 * lunch \
    + BETA_BREAK_AFTER * distance_20 * (morning + lunch) \
    + BETA_DINNER * distance_20 * dinner \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 * lunch \
    + BETA_BREAK_AFTER * distance_21 * (morning + lunch) \
    + BETA_DINNER * distance_21 * dinner \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_9"
results_i_9 = biogeme.estimate()

# %%
print(results_i_9)
# Out:
# Results for model [improve_model_9]
# Output file (HTML):			improve_model_9.html
# Nbr of parameters:		26
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3930.762
# Likelihood ratio test:		2214.304
# Rho square:			0.22
# Rho bar square:			0.215
# Akaike Information Criterion:	7913.524
# Bayesian Information Criterion:	8057.372
# Final gradient norm:		0.08438916
# ASC_ARC        : -2.06[0.177 -11.7 0][0.169 -12.2 0]
# ASC_ATL        : -0.829[0.105 -7.86 3.77e-15][0.107 -7.72 1.2e-14]
# ASC_BC         : -0.552[0.104 -5.33 9.76e-08][0.106 -5.22 1.79e-07]
# ASC_BM         : -1.85[0.164 -11.2 0][0.159 -11.6 0]
# ASC_COP        : -3.41[0.56 -6.09 1.13e-09][0.525 -6.5 7.92e-11]
# ASC_COR        : -0.252[0.138 -1.82 0.0685][0.135 -1.86 0.0626]
# ASC_ELA        : -0.694[0.111 -6.28 3.48e-10][0.109 -6.34 2.32e-10]
# ASC_GIA        : -0.538[0.0941 -5.72 1.09e-08][0.0929 -5.79 7.04e-09]
# ...

# %%
BETA_CAPACITY = Beta('BETA_CAPACITY', 0, -100, 100, 0)

V1 = ASC_KLE \
    + BETA_DISTANCE * distance_1 \
    + BETA_PRICE * MIN_PRICE_1 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_EVA * eva_1 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_1 / 100

V2 = ASC_BC \
    + BETA_DISTANCE * distance_2 \
    + BETA_PRICE * MIN_PRICE_2 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_EVA * eva_2 * lunch \
    + BETA_CAPACITY *  capacity_at_lunch_inside_av_2 / 100

V3 = ASC_BM \
   + BETA_DISTANCE * distance_3 \
    + BETA_PRICE * MIN_PRICE_3 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_EVA * eva_3 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_3 / 100

V4 = ASC_ELA \
   + BETA_DISTANCE * distance_4 \
    + BETA_PRICE * MIN_PRICE_4 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_EVA * eva_4 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_4 / 100

V5 = ASC_INM \
   + BETA_DISTANCE * distance_5 \
    + BETA_PRICE * MIN_PRICE_5 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_EVA * eva_5 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_5 / 100

V6 = ASC_MX \
    + BETA_DISTANCE * distance_6 \
    + BETA_PRICE * MIN_PRICE_6 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_EVA * eva_6 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_6 / 100

V7 = ASC_PH \
    + BETA_DISTANCE * distance_7 \
    + BETA_PRICE * MIN_PRICE_7 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_EVA * eva_7 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_7 / 100

V8 = ASC_ARC \
    + BETA_DISTANCE * distance_8 \
    + BETA_PRICE * MIN_PRICE_8 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_EVA * eva_8 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_8 / 100

V9 = ASC_ATL \
    + BETA_DISTANCE * distance_9 \
    + BETA_PRICE * MIN_PRICE_9 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_EVA * eva_9 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_9 / 100

V10 = ASC_COP \
    + BETA_DISTANCE * distance_10 \
    + BETA_PRICE * MIN_PRICE_10 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_EVA * eva_10 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_10 / 100

V11 = ASC_COR \
    + BETA_DISTANCE * distance_11 \
    + BETA_PRICE * MIN_PRICE_11 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_EVA * eva_11 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_11 / 100

V12 = ASC_GIA \
   + BETA_DISTANCE * distance_12 \
    + BETA_PRICE * MIN_PRICE_12 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_EVA * eva_12 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_12 / 100

V13 = ASC_PAR \
    + BETA_DISTANCE * distance_13 \
    + BETA_PRICE * MIN_PRICE_13 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_EVA * eva_13 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_13 / 100

V14 = ASC_VIN \
    + BETA_DISTANCE * distance_14 \
    + BETA_PRICE * MIN_PRICE_14 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
     + BETA_EVA * eva_14 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_14 / 100

V15 = ASC_ESP \
    + BETA_DISTANCE * distance_15 \
    + BETA_PRICE * MIN_PRICE_15 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
     + BETA_EVA * eva_15 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_15 / 100

V16 = ASC_ORN \
    + BETA_DISTANCE * distance_16 \
    + BETA_PRICE * MIN_PRICE_16 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_EVA * eva_16 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_16 / 100

V17 = ASC_PIZ \
    + BETA_DISTANCE * distance_17 \
    + BETA_PRICE * MIN_PRICE_17 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_EVA * eva_17 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_17 / 100

V18 = ASC_KEB \
    + BETA_DISTANCE * distance_18 \
    + BETA_PRICE * MIN_PRICE_18 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_EVA * eva_18 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_18 / 100

V19 = ASC_SAT \
    + BETA_DISTANCE * distance_19 \
    + BETA_PRICE * MIN_PRICE_19 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_EVA * eva_19 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_19 / 100

V20 = ASC_HOD \
    + BETA_DISTANCE * distance_20 \
    + BETA_PRICE * MIN_PRICE_20 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_EVA * eva_20 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_20 / 100

V21 = ASC_VAL \
    + BETA_DISTANCE * distance_21 \
    + BETA_PRICE * MIN_PRICE_21 * lunch \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_EVA * eva_21 * lunch \
    + BETA_CAPACITY * capacity_at_lunch_inside_av_21 / 100

V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="improve_model_10"
results_i_10 = biogeme.estimate()

# %%
print(results_i_10)
# Out:
# Results for model [improve_model_10]
# Output file (HTML):			improve_model_10.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3752.501
# Likelihood ratio test:		2570.825
# Rho square:			0.255
# Rho bar square:			0.25
# Akaike Information Criterion:	7555.002
# Bayesian Information Criterion:	7693.318
# Final gradient norm:		0.08472149
# ASC_ARC        : -1.82[0.184 -9.91 0][0.17 -10.7 0]
# ASC_ATL        : -0.755[0.108 -6.98 3e-12][0.11 -6.87 6.29e-12]
# ASC_BC         : -0.143[0.115 -1.24 0.215][0.116 -1.23 0.22]
# ASC_BM         : -1.74[0.164 -10.6 0][0.156 -11.1 0]
# ASC_COP        : -3.22[0.569 -5.66 1.53e-08][0.525 -6.12 9.1e-10]
# ASC_COR        : -0.209[0.144 -1.45 0.148][0.142 -1.47 0.141]
# ASC_ELA        : -0.612[0.113 -5.43 5.65e-08][0.111 -5.51 3.49e-08]
# ASC_GIA        : -0.423[0.0972 -4.35 1.36e-05][0.0946 -4.47 7.88e-06]
# ...
