# %%
import biogeme

# %%
import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio

# %%
pandas =pd.read_table("Dataset.dat")

# %%
database = db.Database("Dataset",pandas)

# %%
from headers import *

# %%
exclude = DURATION < 5
database.remove(exclude)

# %%
ASC_BC = Beta('ASC_BC', 0, -100, 100, 0)
ASC_BM = Beta('ASC_BM ', 0, -100, 100, 0)
ASC_ELA = Beta('ASC_ELA ', 0, -100, 100, 0)
ASC_MX = Beta('ASC_MX ', 0, -100, 100, 0)
ASC_PH = Beta('ASC_PH ', 0, -100, 100, 0)
ASC_ATL = Beta('ASC_ATL ', 0, -100, 100, 0)
ASC_COR = Beta('ASC_COR ', 0, -100, 100, 0)
ASC_GIA = Beta('ASC_GIA ', 0, -100, 100, 0)
ASC_PAR = Beta('ASC_PAR ', 0, -100, 100, 0)
ASC_ESP = Beta('ASC_ESP ', 0, -100, 100, 1)
ASC_ORN = Beta('ASC_ORN ', 0, -100, 100, 0)
ASC_PIZ = Beta('ASC_PIZ ', 0, -100, 100, 0)
ASC_KEB = Beta('ASC_KEB ', 0, -100, 100, 0)
ASC_SAT = Beta('ASC_SAT ', 0, -100, 100, 0)
ASC_HOD = Beta('ASC_HOD ', 0, -100, 100, 0)
ASC_VAL = Beta('ASC_VAL ', 0, -100, 100, 0)
ASC_INM = Beta('ASC_INM ', 0, -100, 100, 0)
ASC_VIN = Beta('ASC_VIN', 0, -100, 100, 0)
ASC_COP = Beta('ASC_COP', 0, -100, 100, 0)
ASC_KLE = Beta('ASC_KLE', 0, -100, 100, 0)
ASC_ARC = Beta('ASC_ARC', 0, -100, 100, 0)
BETA_PRICE_STUDENT = Beta('BETA_PRICE_STUDENT', 0, -100, 100, 0)
BETA_PRICE_EMPLOYEE = Beta('BETA_PRICE_EMPLOYEE', 0, -100, 100, 0)
BETA_DISTANCE = Beta('BETA_DISTANCE', 0, -100, 100, 0)
BETA_NO_DISTANCE_AV = Beta('BETA_NO_DISTANCE_AV', 0, -100, 100, 0)
BETA_EVALUATION = Beta('BETA_EVALUATION', 0, -100, 100, 0)

# %%
one = 1
lunch11 = (H_START == 11 * M_START > 29.9) > 0
lunch12 = H_START == 12
lunch13 = H_START == 13
dinner18 = H_START == 18
dinner19 = H_START == 19
morning7 = H_START == 7
morning8 = H_START == 8
morning9 = H_START == 9
morning10 = H_START == 10
morning11 = (H_START == 11 * M_START < 29.8) > 0
afternoon14 = H_START == 14
afternoon15 = H_START == 15
afternoon16 = H_START == 16
afternoon17 = H_START == 17
night20 = H_START == 20
night21 = H_START == 21
night_end21 = H_END == 21
night_end22 = H_END == 22
night = (night20 + night21 + night_end21 + night_end22) > 0
afternoon = (afternoon15 + afternoon16 + afternoon17 + afternoon14) > 0
morning = (morning8 + morning9 + morning10 + morning7 + morning11) > 0
dinner = (dinner18 + dinner19) > 0
lunch = (lunch11 + lunch12 + lunch13) > 0
first_year = SEMESTER == 2
after_lunch = (afternoon + night + dinner) > 0
self_true = SELF == 1
restaurant_true = RESTAURANT == 1
caravan_true = CARAVAN == 1
cafet_true = CAFETERIA == 1
rain_and_cold_max_20 = SUN_AND_HEAT_MIN_20 == 0
perso = SECTION_ID == 5
student_true = STUDENT == 1
self_cafet = (cafet_true + self_true + caravan_true + restaurant_true) > 0

distance_filter_1 = DISTANCE_1 > -1
distance_filter_2 = DISTANCE_2 > -1
distance_filter_3 = DISTANCE_3 > -1
distance_filter_4 = DISTANCE_4 > -1
distance_filter_5 = DISTANCE_5 > -1
distance_filter_6 = DISTANCE_6 > -1
distance_filter_7 = DISTANCE_7 > -1
distance_filter_8 = DISTANCE_8 > -1
distance_filter_9 = DISTANCE_9 > -1
distance_filter_10 = DISTANCE_10 > -1
distance_filter_11 = DISTANCE_11 > -1
distance_filter_12 = DISTANCE_12 > -1
distance_filter_13 = DISTANCE_13 > -1
distance_filter_14 = DISTANCE_14 > -1
distance_filter_15 = DISTANCE_15 > -1
distance_filter_16 = DISTANCE_16 > -1
distance_filter_17 = DISTANCE_17 > -1
distance_filter_18 = DISTANCE_18 > -1
distance_filter_19 = DISTANCE_19 > -1
distance_filter_20 = DISTANCE_20 > -1
distance_filter_21 = DISTANCE_21 > -1
distance_no_av_1 = DISTANCE_1 == -1
distance_no_av_2 = DISTANCE_2 == -1
distance_no_av_3 = DISTANCE_3 == -1
distance_no_av_4 = DISTANCE_4 == -1
distance_no_av_5 = DISTANCE_5 == -1
distance_no_av_6 = DISTANCE_6 == -1
distance_no_av_7 = DISTANCE_7 == -1
distance_no_av_8 = DISTANCE_8 == -1
distance_no_av_9 = DISTANCE_9 == -1
distance_no_av_10 = DISTANCE_10 == -1
distance_no_av_11 = DISTANCE_11 == -1
distance_no_av_12 = DISTANCE_12 == -1
distance_no_av_13 = DISTANCE_13 == -1
distance_no_av_14 = DISTANCE_14 == -1
distance_no_av_15 = DISTANCE_15 == -1
distance_no_av_16 = DISTANCE_16 == -1
distance_no_av_17 = DISTANCE_17 == -1
distance_no_av_18 = DISTANCE_18 == -1
distance_no_av_19 = DISTANCE_19 == -1
distance_no_av_20 = DISTANCE_20 == -1
distance_no_av_21 = DISTANCE_21 == -1

lunch_distance_1 = lunch * distance_filter_1 * DISTANCE_1 / 100
lunch_distance_2 = lunch * distance_filter_2 * DISTANCE_2 / 100
lunch_distance_3 = lunch * distance_filter_3 * DISTANCE_3 / 100
lunch_distance_4 = lunch * distance_filter_4 * DISTANCE_4 / 100
lunch_distance_5 = lunch * distance_filter_5 * DISTANCE_5 / 100
lunch_distance_6 = lunch * distance_filter_6 * DISTANCE_6 / 100
lunch_distance_7 = lunch * distance_filter_7 * DISTANCE_7 / 100
lunch_distance_8 = lunch * distance_filter_8 * DISTANCE_8 / 100
lunch_distance_9 = lunch * distance_filter_9 * DISTANCE_9 / 100
lunch_distance_10 = lunch * distance_filter_10 * DISTANCE_10 / 100
lunch_distance_11 = lunch * distance_filter_11 * DISTANCE_11 / 100
lunch_distance_12 = lunch * distance_filter_12 * DISTANCE_12 / 100
lunch_distance_13 = lunch * distance_filter_13 * DISTANCE_13 / 100
lunch_distance_14 = lunch * distance_filter_14 * DISTANCE_14 / 100
lunch_distance_15 = lunch * distance_filter_15 * DISTANCE_15 / 100
lunch_distance_16 = lunch * distance_filter_16 * DISTANCE_16 / 100
lunch_distance_17 = lunch * distance_filter_17 * DISTANCE_17 / 100
lunch_distance_18 = lunch * distance_filter_18 * DISTANCE_18 / 100
lunch_distance_19 = lunch * distance_filter_19 * DISTANCE_19 / 100
lunch_distance_20 = lunch * distance_filter_20 * DISTANCE_20 / 100
lunch_distance_21 = lunch * distance_filter_21 * DISTANCE_21 / 100

evaluation_filter_1 = EVALUATION_2013_1 > -1
evaluation_filter_2 = EVALUATION_2013_2 > -1
evaluation_filter_3 = EVALUATION_2013_3 > -1
evaluation_filter_4 = EVALUATION_2013_4 > -1
evaluation_filter_5 = EVALUATION_2013_5 > -1
evaluation_filter_6 = EVALUATION_2013_6 > -1
evaluation_filter_7 = EVALUATION_2013_7 > -1
evaluation_filter_8 = EVALUATION_2013_8 > -1
evaluation_filter_9 = EVALUATION_2013_9 > -1
evaluation_filter_10 = EVALUATION_2013_10 > -1
evaluation_filter_11 = EVALUATION_2013_11 > -1
evaluation_filter_12 = EVALUATION_2013_12 > -1
evaluation_filter_13 = EVALUATION_2013_13 > -1
evaluation_filter_14 = EVALUATION_2013_14 > -1
evaluation_filter_15 = EVALUATION_2013_15 > -1
evaluation_filter_16 = EVALUATION_2013_16 > -1
evaluation_filter_17 = EVALUATION_2013_17 > -1
evaluation_filter_18 = EVALUATION_2013_18 > -1
evaluation_filter_19 = EVALUATION_2013_19 > -1
evaluation_filter_20 = EVALUATION_2013_20 > -1
evaluation_filter_21 = EVALUATION_2013_21 > -1
eva_1 = ((evaluation_filter_1 * EVALUATION_2013_1) * self_cafet) * lunch
eva_2 = ((evaluation_filter_2 * EVALUATION_2013_2) * self_cafet) * lunch
eva_3 = ((evaluation_filter_3 * EVALUATION_2013_3) * self_cafet) * lunch
eva_4 = ((evaluation_filter_4 * EVALUATION_2013_4) * self_cafet) * lunch
eva_5 = ((evaluation_filter_5 * EVALUATION_2013_5) * self_cafet) * lunch
eva_6 = ((evaluation_filter_6 * EVALUATION_2013_6) * self_cafet) * lunch
eva_7 = ((evaluation_filter_7 * EVALUATION_2013_7) * self_cafet) * lunch
eva_8 = ((evaluation_filter_8 * EVALUATION_2013_8) * self_cafet) * lunch
eva_9 = ((evaluation_filter_9 * EVALUATION_2013_9) * self_cafet) * lunch
eva_10 = ((evaluation_filter_10 * EVALUATION_2013_10) * self_cafet) * lunch
eva_11 = ((evaluation_filter_11 * EVALUATION_2013_11) * self_cafet) * lunch
eva_12 = ((evaluation_filter_12 * EVALUATION_2013_12) * self_cafet) * lunch
eva_13 = ((evaluation_filter_13 * EVALUATION_2013_13) * self_cafet) * lunch
eva_14 = ((evaluation_filter_14 * EVALUATION_2013_14) * self_cafet) * lunch
eva_15 = ((evaluation_filter_15 * EVALUATION_2013_15) * self_cafet) * lunch
eva_16 = ((evaluation_filter_16 * EVALUATION_2013_16) * self_cafet) * lunch
eva_17 = ((evaluation_filter_17 * EVALUATION_2013_17) * self_cafet) * lunch
eva_18 = ((evaluation_filter_18 * EVALUATION_2013_18) * self_cafet) * lunch
eva_19 = ((evaluation_filter_19 * EVALUATION_2013_19) * self_cafet) * lunch
eva_20 = ((evaluation_filter_20 * EVALUATION_2013_20) * self_cafet) * lunch
eva_21 = ((evaluation_filter_21 * EVALUATION_2013_21) * self_cafet) * lunch

lunch_price_min_student_1 = (lunch * MIN_PRICE_1) * student_true
lunch_price_min_student_2 = (lunch * MIN_PRICE_2) * student_true
lunch_price_min_student_3 = (lunch * MIN_PRICE_3) * student_true
lunch_price_min_student_4 = (lunch * MIN_PRICE_4) * student_true
lunch_price_min_student_5 = (lunch * MIN_PRICE_5) * student_true
lunch_price_min_student_6 = (lunch * MIN_PRICE_6) * student_true
lunch_price_min_student_7 = (lunch * MIN_PRICE_7) * student_true
lunch_price_min_student_8 = (lunch * MIN_PRICE_8) * student_true
lunch_price_min_student_9 = (lunch * MIN_PRICE_9) * student_true
lunch_price_min_student_10 = (lunch * MIN_PRICE_10) * student_true
lunch_price_min_student_11 = (lunch * MIN_PRICE_11) * student_true
lunch_price_min_student_12 = (lunch * MIN_PRICE_12) * student_true
lunch_price_min_student_13 = (lunch * MIN_PRICE_13) * student_true
lunch_price_min_student_14 = (lunch * MIN_PRICE_14) * student_true
lunch_price_min_student_15 = (lunch * MIN_PRICE_15) * student_true
lunch_price_min_student_16 = (lunch * MIN_PRICE_16) * student_true
lunch_price_min_student_17 = (lunch * MIN_PRICE_17) * student_true
lunch_price_min_student_18 = (lunch * MIN_PRICE_18) * student_true
lunch_price_min_student_19 = (lunch * MIN_PRICE_19) * student_true
lunch_price_min_student_20 = (lunch * MIN_PRICE_20) * student_true
lunch_price_min_student_21 = (lunch * MIN_PRICE_21) * student_true
lunch_price_min_employee_1 = (lunch * MIN_PRICE_1) * perso
lunch_price_min_employee_2 = (lunch * MIN_PRICE_2) * perso
lunch_price_min_employee_3 = (lunch * MIN_PRICE_3) * perso
lunch_price_min_employee_4 = (lunch * MIN_PRICE_4) * perso
lunch_price_min_employee_5 = (lunch * MIN_PRICE_5) * perso
lunch_price_min_employee_6 = (lunch * MIN_PRICE_6) * perso
lunch_price_min_employee_7 = (lunch * MIN_PRICE_7) * perso
lunch_price_min_employee_8 = (lunch * MIN_PRICE_8) * perso
lunch_price_min_employee_9 = (lunch * MIN_PRICE_9) * perso
lunch_price_min_employee_10 = (lunch * MIN_PRICE_10) * perso
lunch_price_min_employee_11 = (lunch * MIN_PRICE_11) * perso
lunch_price_min_employee_12 = (lunch * MIN_PRICE_12) * perso
lunch_price_min_employee_13 = (lunch * MIN_PRICE_13) * perso
lunch_price_min_employee_14 = (lunch * MIN_PRICE_14) * perso
lunch_price_min_employee_15 = (lunch * MIN_PRICE_15) * perso
lunch_price_min_employee_16 = (lunch * MIN_PRICE_16) * perso
lunch_price_min_employee_17 = (lunch * MIN_PRICE_17) * perso
lunch_price_min_employee_18 = (lunch * MIN_PRICE_18) * perso
lunch_price_min_employee_19 = (lunch * MIN_PRICE_19) * perso
lunch_price_min_employee_20 = (lunch * MIN_PRICE_20) * perso
lunch_price_min_employee_21 = (lunch * MIN_PRICE_21) * perso

distance_1 = distance_filter_1 * DISTANCE_1 / 100
distance_2 = distance_filter_2 * DISTANCE_2 / 100
distance_3 = distance_filter_3 * DISTANCE_3 / 100
distance_4 = distance_filter_4 * DISTANCE_4 / 100
distance_5 = distance_filter_5 * DISTANCE_5 / 100
distance_6 = distance_filter_6 * DISTANCE_6 / 100
distance_7 = distance_filter_7 * DISTANCE_7 / 100
distance_8 = distance_filter_8 * DISTANCE_8 / 100
distance_9 = distance_filter_9 * DISTANCE_9 / 100
distance_10 = distance_filter_10 * DISTANCE_10 / 100
distance_11 = distance_filter_11 * DISTANCE_11 / 100
distance_12 = distance_filter_12 * DISTANCE_12 / 100
distance_13 = distance_filter_13 * DISTANCE_13 / 100
distance_14 = distance_filter_14 * DISTANCE_14 / 100
distance_15 = distance_filter_15 * DISTANCE_15 / 100
distance_16 = distance_filter_16 * DISTANCE_16 / 100
distance_17 = distance_filter_17 * DISTANCE_17 / 100
distance_18 = distance_filter_18 * DISTANCE_18 / 100
distance_19 = distance_filter_19 * DISTANCE_19 / 100
distance_20 = distance_filter_20 * DISTANCE_20 / 100
distance_21 = distance_filter_21 * DISTANCE_21 / 100

# %%
BETA_EVA = Beta('BETA_EVA', 0, -100, 100, 0)

V1 = ASC_KLE \
    + BETA_DISTANCE * lunch_distance_1 \
    + BETA_EVA * eva_1\
    + BETA_NO_DISTANCE_AV * distance_no_av_1 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_1 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_1 \


V2 = ASC_BC \
    + BETA_DISTANCE * lunch_distance_2 \
    + BETA_EVA * eva_2 \
    + BETA_NO_DISTANCE_AV * distance_no_av_2 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_2 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_2 \

V3 = ASC_BM \
    + BETA_NO_DISTANCE_AV * distance_no_av_3 \
    + BETA_DISTANCE * lunch_distance_3 

V4 = ASC_ELA \
    + BETA_DISTANCE * lunch_distance_4 \
    + BETA_EVA * eva_4  \
    + BETA_NO_DISTANCE_AV * distance_no_av_4 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_4 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_4 \

V5 = ASC_INM \
    + BETA_DISTANCE * lunch_distance_5 \
    + BETA_EVA * eva_5 \
    + BETA_NO_DISTANCE_AV * distance_no_av_5 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_5 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_5 \

V6 = ASC_MX \
    + BETA_DISTANCE * lunch_distance_6 \
    + BETA_EVA * eva_6 \
    + BETA_NO_DISTANCE_AV * distance_no_av_6 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_6 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_6 \

V7 = ASC_PH \
    + BETA_NO_DISTANCE_AV * distance_no_av_7 \
    + BETA_DISTANCE * lunch_distance_7

V8 = ASC_ARC \
    + BETA_DISTANCE * lunch_distance_8 \
    + BETA_EVA * eva_8 \
    + BETA_NO_DISTANCE_AV * distance_no_av_8 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_8 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_8 \

V9 = ASC_ATL \
    + BETA_DISTANCE * lunch_distance_9 \
    + BETA_EVA * eva_9  \
    + BETA_NO_DISTANCE_AV * distance_no_av_9 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_9 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_9 \

V10 = ASC_COP \
    + BETA_DISTANCE * lunch_distance_10 \
    + BETA_EVA * eva_10  \
    + BETA_NO_DISTANCE_AV * distance_no_av_10 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_10 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_10 \

V11 = ASC_COR \
    + BETA_DISTANCE * lunch_distance_11 \
    + BETA_EVA * eva_11  \
    + BETA_NO_DISTANCE_AV * distance_no_av_11 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_11 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_11 \

V12 = ASC_GIA \
    + BETA_DISTANCE * lunch_distance_12 \
    + BETA_EVA * eva_12  \
    + BETA_NO_DISTANCE_AV * distance_no_av_12 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_12 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_12 \

V13 = ASC_PAR \
    + BETA_DISTANCE * lunch_distance_13\
    + BETA_EVA * eva_13  \
    + BETA_NO_DISTANCE_AV * distance_no_av_13 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_13 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_13 \

V14 = ASC_VIN \
    + BETA_DISTANCE * lunch_distance_14 \
    + BETA_EVA * eva_14\
    + BETA_NO_DISTANCE_AV * distance_no_av_14 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_14 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_14 \

V15 = ASC_ESP \
    + BETA_DISTANCE * lunch_distance_15 \
    + BETA_EVA * eva_15  \
    + BETA_NO_DISTANCE_AV * distance_no_av_15 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_15 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_15 \

V16 = ASC_ORN \
    + BETA_DISTANCE * lunch_distance_16 \
    + BETA_EVA * eva_16 \
    + BETA_NO_DISTANCE_AV * distance_no_av_16 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_16 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_16 \

V17 = ASC_PIZ \
    + BETA_NO_DISTANCE_AV * distance_no_av_17 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_17 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_17 \
    + BETA_EVA * eva_17 *self_cafet  \
    + BETA_DISTANCE * lunch_distance_17

V18 = ASC_KEB \
    + BETA_NO_DISTANCE_AV * distance_no_av_18 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_18 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_18 \
    + BETA_DISTANCE * lunch_distance_18 \
    + BETA_EVA * eva_18 *self_cafet  \

V19 = ASC_SAT \
    + BETA_DISTANCE * lunch_distance_19 \
    + BETA_EVA * eva_19  \
    + BETA_NO_DISTANCE_AV * distance_no_av_19 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_19 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_19 \

V20 = ASC_HOD \
    + BETA_DISTANCE * lunch_distance_20 \
    + BETA_EVA * eva_20 \
    + BETA_NO_DISTANCE_AV * distance_no_av_20 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_20 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_20 \

V21 = ASC_VAL \
    + BETA_DISTANCE * lunch_distance_21 \
    + BETA_EVA * eva_21  \
    + BETA_NO_DISTANCE_AV * distance_no_av_21 \
    + BETA_PRICE_STUDENT * lunch_price_min_student_21 \
    + BETA_PRICE_EMPLOYEE * lunch_price_min_employee_21 \

# %%
V = {1: V1,
     2: V2,
     3: V3,
     4: V4,
     5: V5,
     6: V6,
     7: V7,
     8: V8,
     9: V9,
     10: V10,
     11: V11,
     12: V12,
     13: V13,
     14: V14,
     15: V15,
     16: V16,
     17: V17,
     18: V18,
     19: V19,
     20: V20,
     21: V21}
av = {1: OPEN_AV_1,
      2: OPEN_AV_2,
      3: OPEN_AV_3,
      4: OPEN_AV_4,
      5: OPEN_AV_5,
      6: OPEN_AV_6,
      7: OPEN_AV_7,
      8: OPEN_AV_8,
      9: OPEN_AV_9,
      10: OPEN_AV_10,
      11: OPEN_AV_11,
      12: OPEN_AV_12,
      13: OPEN_AV_13,
      14: OPEN_AV_14,
      15: OPEN_AV_15,
      16: OPEN_AV_16,
      17: OPEN_AV_17,
      18: OPEN_AV_18,
      19: OPEN_AV_19,
      20: OPEN_AV_20,
      21: OPEN_AV_21}

# %%
logprob = bioLogLogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database,logprob)
biogeme.modelName="basic_model"
result = biogeme.estimate()

# %%
print(result)
# Out:
# Results for model [basic_model]
# Output file (HTML):			basic_model.html
# Nbr of parameters:		25
# Sample size:			1868
# Excluded data:			0
# Init log likelihood:		-5037.914
# Final log likelihood:		-3472.043
# Likelihood ratio test:		3131.741
# Rho square:			0.311
# Rho bar square:			0.306
# Akaike Information Criterion:	6994.086
# Bayesian Information Criterion:	7132.402
# Final gradient norm:		0.08557039
# ASC_ARC        : -1.51[0.191 -7.86 3.77e-15][0.182 -8.27 2.22e-16]
# ASC_ATL        : -0.67[0.132 -5.07 4.01e-07][0.127 -5.3 1.18e-07]
# ASC_BC         : -0.814[0.125 -6.51 7.57e-11][0.117 -6.99 2.85e-12]
# ASC_BM         : -0.632[0.268 -2.36 0.0184][0.263 -2.41 0.0161]
# ASC_COP        : -0.349[0.545 -0.64 0.522][0.6 -0.581 0.561]
# ASC_COR        : -0.214[0.139 -1.54 0.123][0.137 -1.57 0.117]
# ASC_ELA        : -2.67[0.198 -13.5 0][0.175 -15.3 0]
# ASC_GIA        : -1.03[0.106 -9.73 0][0.113 -9.1 0]
# ASC_HOD        : 1.58[0.302 5.23 1.68e-07][0.361 4.37 1.26e-05]
# ASC_INM        : -4.43[0.32 -13.8 0][0.332 -13.4 0]
# ASC_KEB        : -2.45[0.166 -14.8 0][0.159 -15.4 0]
# ASC_KLE        : -4.26[0.513 -8.29 0][0.516 -8.25 2.22e-16]
# ASC_MX         : -2.47[0.221 -11.2 0][0.161 -15.4 0]
# ASC_ORN        : -0.675[0.153 -4.42 9.65e-06][0.132 -5.13 2.88e-07]
# ASC_PAR        : -0.12[0.111 -1.07 0.284][0.11 -1.09 0.278]
# ASC_PH         : 0.166[0.244 0.68 0.497][0.242 0.684 0.494]
# ASC_PIZ        : -1.59[0.155 -10.3 0][0.143 -11.2 0]
# ASC_SAT        : -2.4[0.164 -14.6 0][0.177 -13.6 0]
# ASC_VAL        : 3.08[0.746 4.12 3.72e-05][1.02 3.02 0.00253]
# ASC_VIN        : -3.99[0.712 -5.6 2.17e-08][0.712 -5.6 2.19e-08]
# BETA_DISTANCE  : -0.702[0.0256 -27.4 0][0.0343 -20.4 0]
# BETA_EVA       : 1.87[0.196 9.53 0][0.103 18.1 0]
# BETA_NO_DISTANCE_AV: -4.92[0.353 -14 0][0.415 -11.9 0]
# BETA_PRICE_EMPLOYEE: -0.281[0.0328 -8.59 0][0.0414 -6.79 1.1e-11]
# BETA_PRICE_STUDENT: -0.451[0.0433 -10.4 0][0.0584 -7.72 1.2e-14]
# ('ASC_ATL ', 'ASC_ARC'):	0.00873	0.345	4.36	1.29e-05	0.00862	0.374	4.68	2.9e-06
# ('ASC_BC', 'ASC_ARC'):	0.00446	0.186	3.32	0.000907	0.00169	0.0795	3.32	0.0009
# ('ASC_BC', 'ASC_ATL '):	0.00566	0.342	-0.975	0.329	0.00187	0.127	-0.896	0.37
# ('ASC_VIN', 'ASC_HOD '):	0.00338	0.0158	-7.24	4.62e-13	0.0042	0.0163	-7.01	2.33e-12
# ('ASC_VIN', 'ASC_INM '):	0.00647	0.0284	0.58	0.562	0.00546	0.0231	0.575	0.565
# ('ASC_VIN', 'ASC_KEB '):	0.00487	0.0413	-2.13	0.0335	0.00427	0.0377	-2.13	0.0334
# ('ASC_VIN', 'ASC_KLE'):	0.00213	0.00582	0.31	0.757	0.00391	0.0106	0.31	0.757
# ('ASC_VIN', 'ASC_MX '):	0.00775	0.0493	-2.06	0.0393	0.00502	0.0439	-2.09	0.0362
# ('ASC_VIN', 'ASC_ORN '):	0.00618	0.0569	-4.6	4.21e-06	0.00483	0.0516	-4.61	3.94e-06
# ('ASC_VIN', 'ASC_PAR '):	0.00485	0.0611	-5.42	6.11e-08	0.00492	0.0627	-5.42	6.08e-08
# ('ASC_VIN', 'ASC_PH '):	0.00281	0.0162	-5.54	2.96e-08	0.00216	0.0125	-5.54	3.03e-08
# ('ASC_VIN', 'ASC_PIZ '):	0.00457	0.0415	-3.31	0.000923	0.00332	0.0327	-3.32	0.000914
# ('ASC_VIN', 'ASC_SAT '):	0.00573	0.0491	-2.2	0.028	0.00536	0.0425	-2.19	0.0289
# ('ASC_VIN', 'ASC_VAL '):	0.00506	0.00953	-6.88	5.93e-12	0.00101	0.0014	-5.69	1.3e-08
# ('BETA_DISTANCE', 'ASC_ARC'):	9.27e-05	0.0189	4.17	3.04e-05	-0.000287	-0.0459	4.3	1.68e-05
# ('BETA_DISTANCE', 'ASC_ATL '):	1.13e-05	0.00333	-0.236	0.814	-5.44e-05	-0.0125	-0.241	0.809
# ('BETA_DISTANCE', 'ASC_BC'):	-6.09e-05	-0.019	0.876	0.381	0.000192	0.0481	0.936	0.349
# ('BETA_DISTANCE', 'ASC_BM '):	5.88e-05	0.00854	-0.26	0.795	-0.000113	-0.0126	-0.264	0.792
# ('BETA_DISTANCE', 'ASC_COP'):	-0.000121	-0.00867	-0.648	0.517	-0.000244	-0.0119	-0.587	0.557
# ('BETA_DISTANCE', 'ASC_COR '):	-5.84e-05	-0.0164	-3.45	0.000571	-4.73e-05	-0.0101	-3.46	0.000548
# ('BETA_DISTANCE', 'ASC_ELA '):	1.96e-05	0.00385	9.86	0	8.68e-05	0.0144	11.1	0
# ('BETA_DISTANCE', 'ASC_GIA '):	-7.46e-05	-0.0275	2.99	0.00281	-0.000223	-0.0573	2.72	0.00645
# ('BETA_DISTANCE', 'ASC_HOD '):	0.000256	0.0331	-7.55	4.24e-14	0.000216	0.0174	-6.29	3.15e-10
# ('BETA_DISTANCE', 'ASC_INM '):	-6.31e-05	-0.00769	11.6	0	-0.00046	-0.0403	11.1	0
# ('BETA_DISTANCE', 'ASC_KEB '):	1.36e-06	0.00032	10.4	0	-0.000235	-0.0431	10.6	0
# ('BETA_DISTANCE', 'ASC_KLE'):	0.000769	0.0584	6.94	3.97e-12	0.00113	0.0638	6.91	4.98e-12
# ('BETA_DISTANCE', 'ASC_MX '):	-0.000186	-0.0328	7.93	2.22e-15	-0.000319	-0.0578	10.7	0
# ('BETA_DISTANCE', 'ASC_ORN '):	-7.22e-05	-0.0184	-0.175	0.861	-0.000134	-0.0296	-0.198	0.843
# ('BETA_DISTANCE', 'ASC_PAR '):	-0.000104	-0.0365	-5.05	4.36e-07	-0.000441	-0.117	-4.89	1.01e-06
# ('BETA_DISTANCE', 'ASC_PH '):	-2.47e-05	-0.00396	-3.54	0.0004	0.000556	0.0669	-3.58	0.000345
# ('BETA_DISTANCE', 'ASC_PIZ '):	-0.00018	-0.0453	5.65	1.63e-08	-0.000313	-0.064	5.99	2.11e-09
# ('BETA_DISTANCE', 'ASC_SAT '):	9.75e-05	0.0232	10.3	0	-5.18e-05	-0.00853	9.4	0
# ('BETA_DISTANCE', 'ASC_VAL '):	-0.000106	-0.00552	-5.06	4.16e-07	0.00134	0.0382	-3.71	0.000206
# ('BETA_DISTANCE', 'ASC_VIN'):	-6.13e-05	-0.00335	4.61	4.06e-06	-0.000467	-0.0191	4.6	4.2e-06
# ('BETA_EVA', 'ASC_ARC'):	-0.00543	-0.145	11.5	0	0.00289	0.154	17.3	0
# ('BETA_EVA', 'ASC_ATL '):	-0.00993	-0.384	9.22	0	0.00111	0.0851	16.2	0
# ('BETA_EVA', 'ASC_BC'):	-0.0118	-0.482	9.62	0	-0.00331	-0.276	15.3	0
# ('BETA_EVA', 'ASC_BM '):	-0.00536	-0.102	7.18	6.89e-13	-0.00436	-0.161	8.41	0
# ('BETA_EVA', 'ASC_COP'):	-0.0128	-0.12	3.69	0.000226	0.0164	0.265	3.81	0.00014
# ('BETA_EVA', 'ASC_COR '):	-0.00118	-0.0433	8.49	0	-0.000183	-0.0131	12.1	0
# ('BETA_EVA', 'ASC_ELA '):	-0.0308	-0.793	12.2	0	-0.0124	-0.687	17.7	0
# ('BETA_EVA', 'ASC_GIA '):	-0.00245	-0.118	12.4	0	-0.0034	-0.292	16.7	0
# ('BETA_EVA', 'ASC_HOD '):	0.0113	0.192	0.879	0.38	0.0153	0.413	0.863	0.388
# ('BETA_EVA', 'ASC_INM '):	-0.0268	-0.428	14.3	0	-0.0161	-0.471	16.1	0
# ('BETA_EVA', 'ASC_KEB '):	-0.0148	-0.456	14	0	-0.00563	-0.344	19.9	0
# ('BETA_EVA', 'ASC_KLE'):	0.0063	0.0627	11.4	0	-0.00205	-0.0386	11.6	0
# ('BETA_EVA', 'ASC_MX '):	-0.0356	-0.823	10.9	0	-0.0104	-0.628	18.2	0
# ('BETA_EVA', 'ASC_ORN '):	-0.017	-0.57	8.21	2.22e-16	-0.00423	-0.312	13.3	0
# ('BETA_EVA', 'ASC_PAR '):	-0.00324	-0.148	8.3	0	-0.000921	-0.0813	12.7	0
# ('BETA_EVA', 'ASC_PH '):	-0.0039	-0.0817	5.23	1.66e-07	0.000159	0.00639	6.47	9.7e-11
# ('BETA_EVA', 'ASC_PIZ '):	-0.0128	-0.423	11.7	0	-0.00253	-0.173	18.2	0
# ('BETA_EVA', 'ASC_SAT '):	-0.0183	-0.57	13.4	0	-0.0111	-0.611	16.8	0
# ('BETA_EVA', 'ASC_VAL '):	0.000464	0.00318	-1.57	0.116	0.0379	0.362	-1.23	0.22
# ('BETA_EVA', 'ASC_VIN'):	-0.0055	-0.0395	7.84	4.44e-15	-0.00178	-0.0243	8.1	4.44e-16
# ('BETA_EVA', 'BETA_DISTANCE'):	-0.000113	-0.0225	13	0	-0.000135	-0.0382	23.4	0
# ('BETA_NO_DISTANCE_AV', 'ASC_
0
# ('BETA_PRICE_EMPLOYEE', 'ASC_ARC'):	-0.00182	-0.291	6.02	1.76e-09	-0.00299	-0.396	6.06	1.36e-09
# ('BETA_PRICE_EMPLOYEE', 'ASC_ATL '):	-0.00167	-0.386	2.63	0.00862	-0.00282	-0.538	2.54	0.011
# ('BETA_PRICE_EMPLOYEE', 'ASC_BC'):	0.000383	0.0933	4.22	2.46e-05	0.000728	0.151	4.53	5.96e-06
# ('BETA_PRICE_EMPLOYEE', 'ASC_BM '):	0.00425	0.484	1.38	0.167	0.00762	0.701	1.49	0.136
# ('BETA_PRICE_EMPLOYEE', 'ASC_COP'):	-0.0105	-0.587	0.119	0.905	-0.0174	-0.701	0.107	0.915
# ('BETA_PRICE_EMPLOYEE', 'ASC_COR '):	-3.13e-05	-0.00688	-0.471	0.638	-9.08e-05	-0.016	-0.469	0.639
# ('BETA_PRICE_EMPLOYEE', 'ASC_ELA '):	0.00284	0.438	12.8	0	0.00482	0.665	15.9	0
# ('BETA_PRICE_EMPLOYEE', 'ASC_GIA '):	0.00164	0.472	7.89	3.11e-15	0.00273	0.582	7.86	4e-15
# ('BETA_PRICE_EMPLOYEE', 'ASC_HOD '):	-0.00664	-0.672	-5.73	1.01e-08	-0.012	-0.802	-4.7	2.57e-06
# ('BETA_PRICE_EMPLOYEE', 'ASC_INM '):	0.00251	0.239	13.2	0	0.00637	0.463	13.2	0
# ('BETA_PRICE_EMPLOYEE', 'ASC_KEB '):	0.00109	0.2	13.3	0	0.00193	0.293	14.2	0
# ('BETA_PRICE_EMPLOYEE', 'ASC_KLE'):	0.00107	0.0635	7.76	8.44e-15	0.00135	0.0633	7.72	1.15e-14
# ('BETA_PRICE_EMPLOYEE', 'ASC_MX '):	0.00113	0.157	10	0	0.002	0.301	14.3	0
# ('BETA_PRICE_EMPLOYEE', 'ASC_ORN '):	0.000557	0.111	2.58	0.00983	0.000719	0.132	2.97	0.003
# ('BETA_PRICE_EMPLOYEE', 'ASC_PAR '):	0.0001	0.0274	-1.4	0.16	8.68e-05	0.019	-1.38	0.166
# ('BETA_PRICE_EMPLOYEE', 'ASC_PH '):	0.00368	0.461	-1.94	0.0523	0.00622	0.62	-2.04	0.0412
# ('BETA_PRICE_EMPLOYEE', 'ASC_PIZ '):	0.000106	0.021	8.34	0	0.000159	0.027	8.9	0
# ('BETA_PRICE_EMPLOYEE', 'ASC_SAT '):	0.00316	0.589	14.4	0	0.0054	0.737	14.2	0
# ('BETA_PRICE_EMPLOYEE', 'ASC_VAL '):	-0.0187	-0.766	-4.35	1.34e-05	-0.0339	-0.803	-3.19	0.00142
# ('BETA_PRICE_EMPLOYEE', 'ASC_VIN'):	0.000162	0.00693	5.2	2.01e-07	0.000362	0.0123	5.2	2.03e-07
# ('BETA_PRICE_EMPLOYEE', 'BETA_DISTANCE'):	1.15e-05	0.0137	10.2	0	-2.39e-05	-0.0168	7.75	9.1e-15
# ('BETA_PRICE_EMPLOYEE', 'BETA_EVA'):	-0.00126	-0.196	-10.5	0	-0.00197	-0.461	-16.8	0
# ('BETA_PRICE_EMPLOYEE', 'BETA_NO_DISTANCE_AV'):	0.000158	0.0137	13.1	0	-6.94e-05	-0.00404	11.1	0
# ('BETA_PRICE_STUDENT', 'ASC_ARC'):	-0.00204	-0.246	5.11	3.2e-07	-0.00417	-0.392	4.98	6.31e-07
# ('BETA_PRICE_STUDENT', 'ASC_ATL '):	-0.00177	-0.31	1.45	0.147	-0.00362	-0.489	1.35	0.178
# ('BETA_PRICE_STUDENT', 'ASC_BC'):	0.000572	0.106	2.84	0.00448	0.00119	0.175	3.01	0.00262
# ('BETA_PRICE_STUDENT', 'ASC_BM '):	0.00492	0.424	0.718	0.473	0.00955	0.623	0.786	0.432
# ('BETA_PRICE_STUDENT', 'ASC_COP'):	-0.0103	-0.435	-0.18	0.857	-0.02	-0.57	-0.16	0.873
# ('BETA_PRICE_STUDENT', 'ASC_COR '):	-5.83e-05	-0.0097	-1.62	0.105	-0.000132	-0.0166	-1.58	0.114
# ('BETA_PRICE_STUDENT', 'ASC_ELA '):	0.00355	0.414	12	0	0.00618	0.604	15.1	0
# ('BETA_PRICE_STUDENT', 'ASC_GIA '):	0.00181	0.395	5.96	2.6e-09	0.00326	0.494	5.88	4.09e-09
# ('BETA_PRICE_STUDENT', 'ASC_HOD '):	-0.00863	-0.661	-6.11	9.75e-10	-0.0145	-0.688	-5.02	5.06e-07
# ('BETA_PRICE_STUDENT', 'ASC_INM '):	0.00303	0.218	12.7	0	0.00797	0.411	12.7	0
# ('BETA_PRICE_STUDENT', 'ASC_KEB '):	0.00123	0.171	12.2	0	0.00228	0.246	12.9	0
# ('BETA_PRICE_STUDENT', 'ASC_KLE'):	0.00147	0.066	7.43	1.07e-13	0.00312	0.103	7.42	1.18e-13
# ('BETA_PRICE_STUDENT', 'ASC_MX '):	0.00164	0.172	9.29	0	0.00301	0.322	13.3	0
# ('BETA_PRICE_STUDENT', 'ASC_ORN '):	0.000572	0.0866	1.45	0.147	0.000796	0.104	1.62	0.105
# ('BETA_PRICE_STUDENT', 'ASC_PAR '):	0.00015	0.0312	-2.8	0.00515	0.000134	0.0209	-2.68	0.00739
# ('BETA_PRICE_STUDENT', 'ASC_PH '):	0.00404	0.383	-2.67	0.00754	0.00762	0.539	-2.85	0.00443
# ('BETA_PRICE_STUDENT', 'ASC_PIZ '):	1.4e-05	0.00209	7.12	1.05e-12	1.42e-05	0.00171	7.42	1.17e-13
# ('BETA_PRICE_STUDENT', 'ASC_SAT '):	0.00389	0.549	13.5	0	0.00722	0.698	13.7	0
# ('BETA_PRICE_STUDENT', 'ASC_VAL '):	-0.0177	-0.55	-4.58	4.72e-06	-0.0281	-0.472	-3.37	0.00076
# ('BETA_PRICE_STUDENT', 'ASC_VIN'):	0.000254	0.00824	4.96	7.1e-07	0.000485	0.0117	4.95	7.34e-07
# ('BETA_PRICE_STUDENT', 'BETA_DISTANCE'):	8.78e-05	0.0791	5.18	2.22e-07	0.000165	0.0822	3.85	0.000116
# ('BETA_PRICE_STUDENT', 'BETA_EVA'):	-0.00184	-0.217	-11.1	0	-0.00309	-0.514	-16.3	0
# ('BETA_PRICE_STUDENT', 'BETA_NO_DISTANCE_AV'):	0.000764	0.05	12.7	0	0.00134	0.0553	10.7	0
# ('BETA_PRICE_STUDENT', 'BETA_PRICE_EMPLOYEE'):	0.000964	0.679	-5.29	1.21e-07	0.00173	0.714	-4.13	3.56e-05
